# %%
import sympy as sp

# Geometric parameters for the legs (constants for a real robot, but slow computation if symbolic)
a0 = 0
a1 = 0.4
a2 = 0.5
a3 = 0.5
a4 = 0.2
d1 = 0.2

# Define symbols for the leg
px, py, pz, q1, q2, q3, q4, s1, c1, s2, c2, s23, c23, phi = sp.symbols(
    'px py pz q1 q2 q3 q4 s1 c1 s2 c2 s23 c23 phi'
)

# Polynomials (Forward Kinematics)
H = sp.sqrt((px + a0)**2 + py**2 - a1**2) - a2 * c2 - a3 * c23 - a4 * sp.sin(phi)
poly1 = -a0 - a1 * c1 + sp.sqrt((px + a0)**2 + py**2 - a1**2) * s1 - px
poly2 = a1 * s1 + sp.sqrt((px + a0)**2 + py**2 - a1**2) * c1 + py
poly3 = -d1 + a2 * s2 + a3 * s23 - a4 * sp.cos(phi) - pz

# Trigonometric identities
id2 = s2**2 + c2**2 - 1
id23 = s23**2 + c23**2 - 1

# Gröbner bases
# Basis 1: Variables [s1, c1]
polys1 = [poly1, poly2]
vars1 = [s1, c1]
gbase1 = sp.groebner(polys1, *vars1, order='grevlex')

# Basis 2: Variables [c2, s2, c23, s23]
polys2 = [H, poly3, id2, id23]
vars2 = [c2, s2, c23, s23]
gbase2 = sp.groebner(polys2, *vars2, order='grevlex')

# Simplify Gröbner bases
gbase1_simplified = [sp.simplify(poly) for poly in gbase1]
gbase2_simplified = [sp.simplify(poly) for poly in gbase2]

# %%
# Symbolic solutions for q1:

# Solve for s1 from the first polynomial in gbase1_simplified
s1_solution = sp.solve(gbase1_simplified[0], s1)

# Compute q1 using asin (arcsin) of s1 solutions
q1 = sp.asin(s1_solution[0])

# %%
# Symbolic solutions for q2 and q3:

# Solve for s23 from the first polynomial in gbase2_simplified
s23_solutions = sp.solve(gbase2_simplified[0], s23)

# Compute q2 and q3 based on s23_solutions[0]
c2_solutions_1 = sp.solve(gbase2_simplified[1].subs(s23, s23_solutions[0]), c2)
q2_1 = sp.acos(c2_solutions_1[0])
q23_1 = sp.asin(s23_solutions[0])
q3_1 = q23_1 - q2_1
q4_1 = -q3_1 - q2_1 + phi

# Compute q2 and q3 based on c23_solutions[1]
c2_solutions_2 = sp.solve(gbase2_simplified[1].subs(s23, s23_solutions[1]), c2)
q2_2 = sp.acos(c2_solutions_2[0])
q23_2 = sp.sin(s23_solutions[1])
q3_2 = q23_2 - q2_2
q4_2 = -q3_2 - q2_2 + phi

# %%
sp.pprint([q1, q2_1, q3_1, q4_1])
# Out:
# ⎡                                                                              ↪
# ⎢    ⎛     ⎛                                             __________________⎞⎞  ↪
# ⎢    ⎜     ⎜       3             2                      ╱   2     2        ⎟⎟  ↪
# ⎢    ⎜0.04⋅⎝25.0⋅px  + 25.0⋅px⋅py  - 4.0⋅px - 10.0⋅py⋅╲╱  px  + py  - 0.16 ⎠⎟  ↪
# ⎢asin⎜──────────────────────────────────────────────────────────────────────⎟, ↪
# ⎢    ⎜                                 __________________                   ⎟  ↪
# ⎢    ⎜                  ⎛  2     2⎞   ╱   2     2                           ⎟  ↪
# ⎣    ⎝                  ⎝px  + py ⎠⋅╲╱  px  + py  - 0.16                    ⎠  ↪
#
# ↪      ⎛                                                                       ↪
# ↪      ⎜                                                                       ↪
# ↪      ⎜           4            2   2            2   2           2             ↪
# ↪      ⎜- 1250.0⋅px  - 2500.0⋅px ⋅py  - 1250.0⋅px ⋅pz  - 500.0⋅px ⋅pz⋅cos(φ) - ↪
# ↪  acos⎜────────────────────────────────────────────────────────────────────── ↪
# ↪      ⎜                                                                       ↪
# ↪      ⎜                                                                       ↪
# ↪      ⎝                                                                       ↪
#
# ↪                                                                              ↪
# ↪                               __________________                             ↪
# ↪          2               2   ╱   2     2                          2          ↪
# ↪  500.0⋅px ⋅pz + 1000.0⋅px ⋅╲╱  px  + py  - 0.16 ⋅sin(φ) - 100.0⋅px ⋅cos(φ) + ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪          2                      2            4            2   2           2  ↪
# ↪  125.0⋅px ⋅cos(2.0⋅φ) + 175.0⋅px  - 1250.0⋅py  - 1250.0⋅py ⋅pz  - 500.0⋅py ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                          __________________                  ↪
# ↪                     2               2   ╱   2     2                          ↪
# ↪ pz⋅cos(φ) - 500.0⋅py ⋅pz + 1000.0⋅py ⋅╲╱  px  + py  - 0.16 ⋅sin(φ) - 100.0⋅p ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                             ________________ ↪
# ↪  2                  2                      2           2   ╱   2     2       ↪
# ↪ y ⋅cos(φ) + 125.0⋅py ⋅cos(2.0⋅φ) + 175.0⋅py  + 500.0⋅pz ⋅╲╱  px  + py  - 0.1 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ __                                                        __________________ ↪
# ↪                    2                      2              ╱   2     2         ↪
# ↪ 6 ⋅sin(φ) + 25.0⋅pz ⋅cos(2.0⋅φ) + 175.0⋅pz  + 200.0⋅pz⋅╲╱  px  + py  - 0.16  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                     ________ ↪
# ↪                       __________________                           ╱         ↪
# ↪                      ╱   2     2                                  ╱          ↪
# ↪ ⋅sin(φ) + 100.0⋅pz⋅╲╱  px  + py  - 0.16 ⋅sin(2.0⋅φ) + 2500.0⋅pz⋅╲╱   - 0.25⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪   6          4   2         4   2         4                   4            4  ↪
# ↪ px  - 0.75⋅px ⋅py  - 0.5⋅px ⋅pz  - 0.2⋅px ⋅pz⋅cos(φ) - 0.2⋅px ⋅pz + 0.3⋅px ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                   0.5                                                        ↪
# ↪ ⎛  2     2       ⎞                    4                  4                   ↪
# ↪ ⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.04⋅px ⋅cos(φ) + 0.065⋅px ⋅cos(2.0⋅φ) + 0.26 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪     4          2   4     2   2   2         2   2                   2   2     ↪
# ↪ 5⋅px  - 0.75⋅px ⋅py  - px ⋅py ⋅pz  - 0.4⋅px ⋅py ⋅pz⋅cos(φ) - 0.4⋅px ⋅py ⋅pz  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                 0.5                                          ↪
# ↪         2   2 ⎛  2     2       ⎞                    2   2                 2  ↪
# ↪ + 0.6⋅px ⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.08⋅px ⋅py ⋅cos(φ) + 0.13⋅px ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪   2                     2   2          2   4         2   3                2  ↪
# ↪ py ⋅cos(2.0⋅φ) + 0.53⋅px ⋅py  - 0.25⋅px ⋅pz  - 0.2⋅px ⋅pz ⋅cos(φ) - 0.2⋅px ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                     0.5                                      ↪
# ↪   3         2   2 ⎛  2     2       ⎞                    2   2                ↪
# ↪ pz  + 0.4⋅px ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.12⋅px ⋅pz ⋅cos(φ) + 0.03⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                   0.5        ↪
# ↪   2   2                     2   2          2    ⎛  2     2       ⎞           ↪
# ↪ px ⋅pz ⋅cos(2.0⋅φ) + 0.26⋅px ⋅pz  + 0.16⋅px ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                  0.5                                         ↪
# ↪           2    ⎛  2     2       ⎞                         2                  ↪
# ↪  + 0.08⋅px ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.122⋅px ⋅pz⋅cos(φ) + 0.01 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪     2                        2                        2              2 ⎛  2  ↪
# ↪ 2⋅px ⋅pz⋅cos(2.0⋅φ) + 0.01⋅px ⋅pz⋅cos(3.0⋅φ) + 0.12⋅px ⋅pz - 0.246⋅px ⋅⎝px   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪              0.5                                      0.5                    ↪
# ↪     2       ⎞                     2 ⎛  2     2       ⎞                       ↪
# ↪ + py  - 0.16⎠   ⋅sin(φ) + 0.016⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) - 0.006 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                        0.5                                                   ↪
# ↪    2 ⎛  2     2       ⎞                          2                   2    2  ↪
# ↪ ⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0276⋅px ⋅cos(φ) - 0.0004⋅px ⋅cos ( ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                   2                      2                       2           ↪
# ↪ 2.0⋅φ) - 0.0418⋅px ⋅cos(2.0⋅φ) + 0.002⋅px ⋅cos(3.0⋅φ) - 0.0274⋅px  - 0.25⋅py ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪ 6         4   2         4                   4            4 ⎛  2     2        ↪
# ↪   - 0.5⋅py ⋅pz  - 0.2⋅py ⋅pz⋅cos(φ) - 0.2⋅py ⋅pz + 0.3⋅py ⋅⎝px  + py  - 0.16 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪  0.5                                                                         ↪
# ↪ ⎞                    4                  4                      4          2  ↪
# ↪ ⎠   ⋅sin(φ) - 0.04⋅py ⋅cos(φ) + 0.065⋅py ⋅cos(2.0⋅φ) + 0.265⋅py  - 0.25⋅py ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                        0.5   ↪
# ↪   4         2   3                2   3         2   2 ⎛  2     2       ⎞      ↪
# ↪ pz  - 0.2⋅py ⋅pz ⋅cos(φ) - 0.2⋅py ⋅pz  + 0.4⋅py ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅s ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                2   2                 2   2                     2   2         ↪
# ↪ in(φ) - 0.12⋅py ⋅pz ⋅cos(φ) + 0.03⋅py ⋅pz ⋅cos(2.0⋅φ) + 0.26⋅py ⋅pz  + 0.16⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                          0.5                                        0.5      ↪
# ↪   2    ⎛  2     2       ⎞                    2    ⎛  2     2       ⎞         ↪
# ↪ py ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.08⋅py ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin( ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                  2                     2                        2            ↪
# ↪ 2.0⋅φ) + 0.122⋅py ⋅pz⋅cos(φ) + 0.012⋅py ⋅pz⋅cos(2.0⋅φ) + 0.01⋅py ⋅pz⋅cos(3.0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                 0.5                          ↪
# ↪              2              2 ⎛  2     2       ⎞                     2 ⎛  2  ↪
# ↪ ⋅φ) + 0.12⋅py ⋅pz - 0.246⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.016⋅py ⋅⎝px   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪              0.5                                          0.5                ↪
# ↪     2       ⎞                         2 ⎛  2     2       ⎞                   ↪
# ↪ + py  - 0.16⎠   ⋅sin(2.0⋅φ) - 0.006⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪         2                   2    2                   2                       ↪
# ↪ .0276⋅py ⋅cos(φ) - 0.0004⋅py ⋅cos (2.0⋅φ) - 0.0418⋅py ⋅cos(2.0⋅φ) + 0.002⋅py ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                       0.5                    ↪
# ↪ 2                       2         4 ⎛  2     2       ⎞                     4 ↪
# ↪  ⋅cos(3.0⋅φ) - 0.0274⋅py  + 0.1⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.005⋅pz  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                      0.5                     ↪
# ↪                       4          3 ⎛  2     2       ⎞                    3 ⎛ ↪
# ↪ ⋅cos(2.0⋅φ) + 0.035⋅pz  + 0.08⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.04⋅pz ⋅⎝ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                  0.5                                                         ↪
# ↪   2     2       ⎞                        3                  3                ↪
# ↪ px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.03⋅pz ⋅cos(φ) + 0.004⋅pz ⋅cos(2.0⋅φ) + 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                               0.5            ↪
# ↪        3                      3           2 ⎛  2     2       ⎞               ↪
# ↪ .002⋅pz ⋅cos(3.0⋅φ) + 0.028⋅pz  - 0.122⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                            0.5                                          0.5  ↪
# ↪        2 ⎛  2     2       ⎞                         2 ⎛  2     2       ⎞     ↪
# ↪ .024⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.002⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                      2                   2    2                   2          ↪
# ↪ sin(3.0⋅φ) + 0.018⋅pz ⋅cos(φ) + 0.0004⋅pz ⋅cos (2.0⋅φ) - 0.0082⋅pz ⋅cos(2.0⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                       0.5    ↪
# ↪               2                       2             ⎛  2     2       ⎞       ↪
# ↪ φ) + 0.0012⋅pz ⋅cos(3.0⋅φ) - 0.0258⋅pz  - 0.0552⋅pz⋅⎝px  + py  - 0.16⎠   ⋅si ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                    0.5                                       ↪
# ↪                  ⎛  2     2       ⎞                           ⎛  2     2     ↪
# ↪ n(φ) - 0.0256⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.0008⋅pz⋅⎝px  + py  - 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪     0.5                                          0.5                         ↪
# ↪    ⎞                           ⎛  2     2       ⎞                            ↪
# ↪ .16⎠   ⋅sin(3.0⋅φ) - 0.0004⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(4.0⋅φ) - 0.01372⋅pz ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                         2                                                    ↪
# ↪ ⋅cos(φ) + 0.00016⋅pz⋅cos (2.0⋅φ) - 0.0036⋅pz⋅cos(2.0⋅φ) - 0.00228⋅pz⋅cos(3.0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                              0.5                             ↪
# ↪                            ⎛  2     2       ⎞                     ⎛  2     2 ↪
# ↪ ⋅φ) - 0.01256⋅pz + 0.02196⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.00576⋅⎝px  + py  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪         0.5                                        0.5                       ↪
# ↪        ⎞                         ⎛  2     2       ⎞                        ⎛ ↪
# ↪  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.00196⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) - 8.0e-5⋅⎝ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                  0.5                                                         ↪
# ↪   2     2       ⎞                                             2              ↪
# ↪ px  + py  - 0.16⎠   ⋅sin(4.0⋅φ) - 0.003224⋅cos(φ) + 8.0e-5⋅cos (2.0⋅φ) + 0.0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________________________________                           ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ 04656⋅cos(2.0⋅φ) - 0.000488⋅cos(3.0⋅φ) - 0.001024  + 75.0⋅pz⋅cos(φ) + 10.0⋅p ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                       __________________     ↪
# ↪                                                      ╱   2     2             ↪
# ↪ z⋅cos(2.0⋅φ) + 5.0⋅pz⋅cos(3.0⋅φ) + 70.0⋅pz - 105.0⋅╲╱  px  + py  - 0.16 ⋅sin ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪               __________________                     __________________      ↪
# ↪              ╱   2     2                            ╱   2     2              ↪
# ↪ (φ) + 20.0⋅╲╱  px  + py  - 0.16 ⋅sin(2.0⋅φ) - 5.0⋅╲╱  px  + py  - 0.16 ⋅sin( ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                    _________________________________________________________ ↪
# ↪                   ╱                                                          ↪
# ↪                  ╱           6          4   2         4   2         4        ↪
# ↪ 3.0⋅φ) + 500.0⋅╲╱   - 0.25⋅px  - 0.75⋅px ⋅py  - 0.5⋅px ⋅pz  - 0.2⋅px ⋅pz⋅cos ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                              0.5                             ↪
# ↪             4            4 ⎛  2     2       ⎞                    4           ↪
# ↪ (φ) - 0.2⋅px ⋅pz + 0.3⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.04⋅px ⋅cos(φ) +  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪         4                      4          2   4     2   2   2         2   2  ↪
# ↪ 0.065⋅px ⋅cos(2.0⋅φ) + 0.265⋅px  - 0.75⋅px ⋅py  - px ⋅py ⋅pz  - 0.4⋅px ⋅py ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                            0.5               ↪
# ↪                   2   2            2   2 ⎛  2     2       ⎞                  ↪
# ↪ pz⋅cos(φ) - 0.4⋅px ⋅py ⋅pz + 0.6⋅px ⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.08 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪    2   2                 2   2                     2   2          2   4      ↪
# ↪ ⋅px ⋅py ⋅cos(φ) + 0.13⋅px ⋅py ⋅cos(2.0⋅φ) + 0.53⋅px ⋅py  - 0.25⋅px ⋅pz  - 0. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                0.5           ↪
# ↪     2   3                2   3         2   2 ⎛  2     2       ⎞              ↪
# ↪ 2⋅px ⋅pz ⋅cos(φ) - 0.2⋅px ⋅pz  + 0.4⋅px ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) -  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪        2   2                 2   2                     2   2          2    ⎛ ↪
# ↪ 0.12⋅px ⋅pz ⋅cos(φ) + 0.03⋅px ⋅pz ⋅cos(2.0⋅φ) + 0.26⋅px ⋅pz  + 0.16⋅px ⋅pz⋅⎝ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                  0.5                                        0.5              ↪
# ↪   2     2       ⎞                    2    ⎛  2     2       ⎞                 ↪
# ↪ px  + py  - 0.16⎠   ⋅sin(φ) + 0.08⋅px ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪          2                     2                        2                    ↪
# ↪  0.122⋅px ⋅pz⋅cos(φ) + 0.012⋅px ⋅pz⋅cos(2.0⋅φ) + 0.01⋅px ⋅pz⋅cos(3.0⋅φ) + 0. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                         0.5                                  ↪
# ↪      2              2 ⎛  2     2       ⎞                     2 ⎛  2     2    ↪
# ↪ 12⋅px ⋅pz - 0.246⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.016⋅px ⋅⎝px  + py  -  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪      0.5                                          0.5                        ↪
# ↪     ⎞                         2 ⎛  2     2       ⎞                           ↪
# ↪ 0.16⎠   ⋅sin(2.0⋅φ) - 0.006⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0276⋅px ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                2 ⎛  2     2  ↪
# ↪                                                     - 1250.0⋅px ⋅⎝px  + py   ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪ 2                   2    2                   2                      2        ↪
# ↪  ⋅cos(φ) - 0.0004⋅px ⋅cos (2.0⋅φ) - 0.0418⋅px ⋅cos(2.0⋅φ) + 0.002⋅px ⋅cos(3. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪        0.5                                                   0.5             ↪
# ↪       ⎞              2                   2 ⎛  2     2       ⎞              2 ↪
# ↪ - 0.16⎠    + 750.0⋅px ⋅sin(φ) - 1250.0⋅py ⋅⎝px  + py  - 0.16⎠    + 750.0⋅py  ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                 2          6         4   2         4                   4     ↪
# ↪ 0⋅φ) - 0.0274⋅px  - 0.25⋅py  - 0.5⋅py ⋅pz  - 0.2⋅py ⋅pz⋅cos(φ) - 0.2⋅py ⋅pz  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                        0.5                                   ↪
# ↪                    2 ⎛  2     2       ⎞              2                   ⎛   ↪
# ↪ ⋅sin(φ) - 1250.0⋅pz ⋅⎝px  + py  - 0.16⎠    + 250.0⋅pz ⋅sin(φ) - 500.0⋅pz⋅⎝px ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                             0.5                                              ↪
# ↪         4 ⎛  2     2       ⎞                    4                  4         ↪
# ↪ + 0.3⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.04⋅py ⋅cos(φ) + 0.065⋅py ⋅cos(2.0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                0.5                                     0.5                   ↪
# ↪ 2     2       ⎞                      ⎛  2     2       ⎞                      ↪
# ↪   + py  - 0.16⎠   ⋅cos(φ) - 500.0⋅pz⋅⎝px  + py  - 0.16⎠    + 100.0⋅pz⋅sin(φ) ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪               4          2   4         2   3                2   3         2  ↪
# ↪ ⋅φ) + 0.265⋅py  - 0.25⋅py ⋅pz  - 0.2⋅py ⋅pz ⋅cos(φ) - 0.2⋅py ⋅pz  + 0.4⋅py ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                 0.5                          ↪
# ↪                               ⎛  2     2       ⎞                  ⎛  2     2 ↪
# ↪  + 50.0⋅pz⋅sin(2.0⋅φ) - 100.0⋅⎝px  + py  - 0.16⎠   ⋅cos(φ) + 50.0⋅⎝px  + py  ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                       0.5                                                    ↪
# ↪   2 ⎛  2     2       ⎞                    2   2                 2   2        ↪
# ↪ pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.12⋅py ⋅pz ⋅cos(φ) + 0.03⋅py ⋅pz ⋅cos(2. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪         0.5                                     0.5                          ↪
# ↪        ⎞                      ⎛  2     2       ⎞                             ↪
# ↪  - 0.16⎠   ⋅cos(2.0⋅φ) + 50.0⋅⎝px  + py  - 0.16⎠    - 100.0⋅sin(φ) + 10.0⋅si ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                     0.5                      ↪
# ↪               2   2          2    ⎛  2     2       ⎞                    2    ↪
# ↪ 0⋅φ) + 0.26⋅py ⋅pz  + 0.16⋅py ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.08⋅py ⋅pz ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ n(2.0⋅φ)                                                                     ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                    0.5                                                       ↪
# ↪  ⎛  2     2       ⎞                         2                     2          ↪
# ↪ ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.122⋅py ⋅pz⋅cos(φ) + 0.012⋅py ⋅pz⋅cos(2 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                            0 ↪
# ↪                2                        2              2 ⎛  2     2       ⎞  ↪
# ↪ .0⋅φ) + 0.01⋅py ⋅pz⋅cos(3.0⋅φ) + 0.12⋅py ⋅pz - 0.246⋅py ⋅⎝px  + py  - 0.16⎠  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪ .5                                      0.5                                  ↪
# ↪                     2 ⎛  2     2       ⎞                         2 ⎛  2      ↪
# ↪   ⋅sin(φ) + 0.016⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) - 0.006⋅py ⋅⎝px  + py ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪          0.5                                                                 ↪
# ↪ 2       ⎞                          2                   2    2                ↪
# ↪   - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0276⋅py ⋅cos(φ) - 0.0004⋅py ⋅cos (2.0⋅φ) - 0.041 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪     2                      2                       2         4 ⎛  2     2    ↪
# ↪ 8⋅py ⋅cos(2.0⋅φ) + 0.002⋅py ⋅cos(3.0⋅φ) - 0.0274⋅py  + 0.1⋅pz ⋅⎝px  + py  -  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪      0.5                                                                     ↪
# ↪     ⎞                     4                      4          3 ⎛  2     2     ↪
# ↪ 0.16⎠   ⋅sin(φ) + 0.005⋅pz ⋅cos(2.0⋅φ) + 0.035⋅pz  + 0.08⋅pz ⋅⎝px  + py  - 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪     0.5                                     0.5                              ↪
# ↪    ⎞                    3 ⎛  2     2       ⎞                        3        ↪
# ↪ .16⎠   ⋅sin(φ) + 0.04⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.03⋅pz ⋅cos(φ) ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪            3                      3                      3           2 ⎛  2  ↪
# ↪  + 0.004⋅pz ⋅cos(2.0⋅φ) + 0.002⋅pz ⋅cos(3.0⋅φ) + 0.028⋅pz  - 0.122⋅pz ⋅⎝px   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪              0.5                                      0.5                    ↪
# ↪     2       ⎞                     2 ⎛  2     2       ⎞                       ↪
# ↪ + py  - 0.16⎠   ⋅sin(φ) + 0.024⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.002 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                        0.5                                                   ↪
# ↪    2 ⎛  2     2       ⎞                         2                   2    2   ↪
# ↪ ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.018⋅pz ⋅cos(φ) + 0.0004⋅pz ⋅cos (2 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                  2                       2                       2           ↪
# ↪ .0⋅φ) - 0.0082⋅pz ⋅cos(2.0⋅φ) + 0.0012⋅pz ⋅cos(3.0⋅φ) - 0.0258⋅pz  - 0.0552⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                      0.5                                      0.5            ↪
# ↪    ⎛  2     2       ⎞                       ⎛  2     2       ⎞               ↪
# ↪ pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.0256⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ...
# ↪ ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0276⋅px ⋅cos(φ) - 0.0004⋅px ⋅cos (2.0⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪               2                      2                       2          6    ↪
# ↪ φ) - 0.0418⋅px ⋅cos(2.0⋅φ) + 0.002⋅px ⋅cos(3.0⋅φ) - 0.0274⋅px  - 0.25⋅py  -  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                          0.5 ↪
# ↪       4   2         4                   4            4 ⎛  2     2       ⎞    ↪
# ↪ 0.5⋅py ⋅pz  - 0.2⋅py ⋅pz⋅cos(φ) - 0.2⋅py ⋅pz + 0.3⋅py ⋅⎝px  + py  - 0.16⎠    ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                  4                  4                      4          2   4  ↪
# ↪ ⋅sin(φ) - 0.04⋅py ⋅cos(φ) + 0.065⋅py ⋅cos(2.0⋅φ) + 0.265⋅py  - 0.25⋅py ⋅pz   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                    0.5       ↪
# ↪         2   3                2   3         2   2 ⎛  2     2       ⎞          ↪
# ↪ - 0.2⋅py ⋅pz ⋅cos(φ) - 0.2⋅py ⋅pz  + 0.4⋅py ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                     2           2            ↪
# ↪                                             250.0⋅px  + 250.0⋅py  + 250.0⋅pz ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪            2   2                 2   2                     2   2          2  ↪
# ↪ ) - 0.12⋅py ⋅pz ⋅cos(φ) + 0.03⋅py ⋅pz ⋅cos(2.0⋅φ) + 0.26⋅py ⋅pz  + 0.16⋅py ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                          0.5                 ↪
# ↪ 2                                      ⎛  2     2       ⎞                    ↪
# ↪   + 100.0⋅pz⋅cos(φ) + 100.0⋅pz - 100.0⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 20.0⋅c ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                      0.5                                        0.5          ↪
# ↪    ⎛  2     2       ⎞                    2    ⎛  2     2       ⎞             ↪
# ↪ pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.08⋅py ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ os(φ) - 20.0                                                                 ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪              2                     2                        2                ↪
# ↪ φ) + 0.122⋅py ⋅pz⋅cos(φ) + 0.012⋅py ⋅pz⋅cos(2.0⋅φ) + 0.01⋅py ⋅pz⋅cos(3.0⋅φ)  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                             0.5                              ↪
# ↪          2              2 ⎛  2     2       ⎞                     2 ⎛  2      ↪
# ↪ + 0.12⋅py ⋅pz - 0.246⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.016⋅py ⋅⎝px  + py ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪          0.5                                          0.5                    ↪
# ↪ 2       ⎞                         2 ⎛  2     2       ⎞                       ↪
# ↪   - 0.16⎠   ⋅sin(2.0⋅φ) - 0.006⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.027 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪     2                   2    2                   2                      2    ↪
# ↪ 6⋅py ⋅cos(φ) - 0.0004⋅py ⋅cos (2.0⋅φ) - 0.0418⋅py ⋅cos(2.0⋅φ) + 0.002⋅py ⋅co ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                   0.5                        ↪
# ↪                     2         4 ⎛  2     2       ⎞                     4     ↪
# ↪ s(3.0⋅φ) - 0.0274⋅py  + 0.1⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.005⋅pz ⋅cos ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                  0.5                         ↪
# ↪                   4          3 ⎛  2     2       ⎞                    3 ⎛  2  ↪
# ↪ (2.0⋅φ) + 0.035⋅pz  + 0.08⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.04⋅pz ⋅⎝px   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪              0.5                                                             ↪
# ↪     2       ⎞                        3                  3                    ↪
# ↪ + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.03⋅pz ⋅cos(φ) + 0.004⋅pz ⋅cos(2.0⋅φ) + 0.002 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                           0.5                ↪
# ↪    3                      3           2 ⎛  2     2       ⎞                   ↪
# ↪ ⋅pz ⋅cos(3.0⋅φ) + 0.028⋅pz  - 0.122⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.024 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                        0.5                                          0.5      ↪
# ↪    2 ⎛  2     2       ⎞                         2 ⎛  2     2       ⎞         ↪
# ↪ ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.002⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin( ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                  2                   2    2                   2              ↪
# ↪ 3.0⋅φ) + 0.018⋅pz ⋅cos(φ) + 0.0004⋅pz ⋅cos (2.0⋅φ) - 0.0082⋅pz ⋅cos(2.0⋅φ) + ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                   0.5        ↪
# ↪           2                       2             ⎛  2     2       ⎞           ↪
# ↪  0.0012⋅pz ⋅cos(3.0⋅φ) - 0.0258⋅pz  - 0.0552⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                0.5                                           ↪
# ↪              ⎛  2     2       ⎞                           ⎛  2     2       ⎞ ↪
# ↪  - 0.0256⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.0008⋅pz⋅⎝px  + py  - 0.16⎠ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪ 0.5                                          0.5                             ↪
# ↪                            ⎛  2     2       ⎞                                ↪
# ↪    ⋅sin(3.0⋅φ) - 0.0004⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(4.0⋅φ) - 0.01372⋅pz⋅cos ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                     2                                                        ↪
# ↪ (φ) + 0.00016⋅pz⋅cos (2.0⋅φ) - 0.0036⋅pz⋅cos(2.0⋅φ) - 0.00228⋅pz⋅cos(3.0⋅φ)  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                          0.5                                 ↪
# ↪                        ⎛  2     2       ⎞                     ⎛  2     2     ↪
# ↪ - 0.01256⋅pz + 0.02196⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.00576⋅⎝px  + py  - 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪     0.5                                        0.5                           ↪
# ↪    ⎞                         ⎛  2     2       ⎞                        ⎛  2  ↪
# ↪ .16⎠   ⋅sin(2.0⋅φ) + 0.00196⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) - 8.0e-5⋅⎝px   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪              0.5                                                             ↪
# ↪     2       ⎞                                             2                  ↪
# ↪ + py  - 0.16⎠   ⋅sin(4.0⋅φ) - 0.003224⋅cos(φ) + 8.0e-5⋅cos (2.0⋅φ) + 0.00465 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ______________________________________________                       ⎞⎤
# ↪                                                                      ⎟⎥
# ↪                                                                      ⎟⎥
# ↪ 6⋅cos(2.0⋅φ) - 0.000488⋅cos(3.0⋅φ) - 0.001024  + 2.0⋅cos(2.0⋅φ) - 2.0⎟⎥
# ↪ ─────────────────────────────────────────────────────────────────────⎟⎥
# ↪                                                                      ⎟⎥
# ↪                                                                      ⎟⎥
# ↪                                                                      ⎠⎦

# %%
sp.pprint([q1, q2_2, q3_2, q4_2])
# Out:
# ⎡                                                                              ↪
# ⎢    ⎛     ⎛                                             __________________⎞⎞  ↪
# ⎢    ⎜     ⎜       3             2                      ╱   2     2        ⎟⎟  ↪
# ⎢    ⎜0.04⋅⎝25.0⋅px  + 25.0⋅px⋅py  - 4.0⋅px - 10.0⋅py⋅╲╱  px  + py  - 0.16 ⎠⎟  ↪
# ⎢asin⎜──────────────────────────────────────────────────────────────────────⎟, ↪
# ⎢    ⎜                                 __________________                   ⎟  ↪
# ⎢    ⎜                  ⎛  2     2⎞   ╱   2     2                           ⎟  ↪
# ⎣    ⎝                  ⎝px  + py ⎠⋅╲╱  px  + py  - 0.16                    ⎠  ↪
#
# ↪      ⎛                                                                       ↪
# ↪      ⎜                                                                       ↪
# ↪      ⎜           4            2   2            2   2           2             ↪
# ↪      ⎜- 1250.0⋅px  - 2500.0⋅px ⋅py  - 1250.0⋅px ⋅pz  - 500.0⋅px ⋅pz⋅cos(φ) - ↪
# ↪  acos⎜────────────────────────────────────────────────────────────────────── ↪
# ↪      ⎜                                                                       ↪
# ↪      ⎜                                                                       ↪
# ↪      ⎝                                                                       ↪
#
# ↪                                                                              ↪
# ↪                               __________________                             ↪
# ↪          2               2   ╱   2     2                          2          ↪
# ↪  500.0⋅px ⋅pz + 1000.0⋅px ⋅╲╱  px  + py  - 0.16 ⋅sin(φ) - 100.0⋅px ⋅cos(φ) + ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪          2                      2            4            2   2           2  ↪
# ↪  125.0⋅px ⋅cos(2.0⋅φ) + 175.0⋅px  - 1250.0⋅py  - 1250.0⋅py ⋅pz  - 500.0⋅py ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                          __________________                  ↪
# ↪                     2               2   ╱   2     2                          ↪
# ↪ pz⋅cos(φ) - 500.0⋅py ⋅pz + 1000.0⋅py ⋅╲╱  px  + py  - 0.16 ⋅sin(φ) - 100.0⋅p ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                             ________________ ↪
# ↪  2                  2                      2           2   ╱   2     2       ↪
# ↪ y ⋅cos(φ) + 125.0⋅py ⋅cos(2.0⋅φ) + 175.0⋅py  + 500.0⋅pz ⋅╲╱  px  + py  - 0.1 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ __                                                        __________________ ↪
# ↪                    2                      2              ╱   2     2         ↪
# ↪ 6 ⋅sin(φ) + 25.0⋅pz ⋅cos(2.0⋅φ) + 175.0⋅pz  + 200.0⋅pz⋅╲╱  px  + py  - 0.16  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                     ________ ↪
# ↪                       __________________                           ╱         ↪
# ↪                      ╱   2     2                                  ╱          ↪
# ↪ ⋅sin(φ) + 100.0⋅pz⋅╲╱  px  + py  - 0.16 ⋅sin(2.0⋅φ) - 2500.0⋅pz⋅╲╱   - 0.25⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪   6          4   2         4   2         4                   4            4  ↪
# ↪ px  - 0.75⋅px ⋅py  - 0.5⋅px ⋅pz  - 0.2⋅px ⋅pz⋅cos(φ) - 0.2⋅px ⋅pz + 0.3⋅px ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                   0.5                                                        ↪
# ↪ ⎛  2     2       ⎞                    4                  4                   ↪
# ↪ ⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.04⋅px ⋅cos(φ) + 0.065⋅px ⋅cos(2.0⋅φ) + 0.26 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪     4          2   4     2   2   2         2   2                   2   2     ↪
# ↪ 5⋅px  - 0.75⋅px ⋅py  - px ⋅py ⋅pz  - 0.4⋅px ⋅py ⋅pz⋅cos(φ) - 0.4⋅px ⋅py ⋅pz  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                 0.5                                          ↪
# ↪         2   2 ⎛  2     2       ⎞                    2   2                 2  ↪
# ↪ + 0.6⋅px ⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.08⋅px ⋅py ⋅cos(φ) + 0.13⋅px ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪   2                     2   2          2   4         2   3                2  ↪
# ↪ py ⋅cos(2.0⋅φ) + 0.53⋅px ⋅py  - 0.25⋅px ⋅pz  - 0.2⋅px ⋅pz ⋅cos(φ) - 0.2⋅px ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                     0.5                                      ↪
# ↪   3         2   2 ⎛  2     2       ⎞                    2   2                ↪
# ↪ pz  + 0.4⋅px ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.12⋅px ⋅pz ⋅cos(φ) + 0.03⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                   0.5        ↪
# ↪   2   2                     2   2          2    ⎛  2     2       ⎞           ↪
# ↪ px ⋅pz ⋅cos(2.0⋅φ) + 0.26⋅px ⋅pz  + 0.16⋅px ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                  0.5                                         ↪
# ↪           2    ⎛  2     2       ⎞                         2                  ↪
# ↪  + 0.08⋅px ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.122⋅px ⋅pz⋅cos(φ) + 0.01 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪     2                        2                        2              2 ⎛  2  ↪
# ↪ 2⋅px ⋅pz⋅cos(2.0⋅φ) + 0.01⋅px ⋅pz⋅cos(3.0⋅φ) + 0.12⋅px ⋅pz - 0.246⋅px ⋅⎝px   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪              0.5                                      0.5                    ↪
# ↪     2       ⎞                     2 ⎛  2     2       ⎞                       ↪
# ↪ + py  - 0.16⎠   ⋅sin(φ) + 0.016⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) - 0.006 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                        0.5                                                   ↪
# ↪    2 ⎛  2     2       ⎞                          2                   2    2  ↪
# ↪ ⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0276⋅px ⋅cos(φ) - 0.0004⋅px ⋅cos ( ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                   2                      2                       2           ↪
# ↪ 2.0⋅φ) - 0.0418⋅px ⋅cos(2.0⋅φ) + 0.002⋅px ⋅cos(3.0⋅φ) - 0.0274⋅px  - 0.25⋅py ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪ 6         4   2         4                   4            4 ⎛  2     2        ↪
# ↪   - 0.5⋅py ⋅pz  - 0.2⋅py ⋅pz⋅cos(φ) - 0.2⋅py ⋅pz + 0.3⋅py ⋅⎝px  + py  - 0.16 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪  0.5                                                                         ↪
# ↪ ⎞                    4                  4                      4          2  ↪
# ↪ ⎠   ⋅sin(φ) - 0.04⋅py ⋅cos(φ) + 0.065⋅py ⋅cos(2.0⋅φ) + 0.265⋅py  - 0.25⋅py ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                        0.5   ↪
# ↪   4         2   3                2   3         2   2 ⎛  2     2       ⎞      ↪
# ↪ pz  - 0.2⋅py ⋅pz ⋅cos(φ) - 0.2⋅py ⋅pz  + 0.4⋅py ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅s ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                2   2                 2   2                     2   2         ↪
# ↪ in(φ) - 0.12⋅py ⋅pz ⋅cos(φ) + 0.03⋅py ⋅pz ⋅cos(2.0⋅φ) + 0.26⋅py ⋅pz  + 0.16⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                          0.5                                        0.5      ↪
# ↪   2    ⎛  2     2       ⎞                    2    ⎛  2     2       ⎞         ↪
# ↪ py ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.08⋅py ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin( ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                  2                     2                        2            ↪
# ↪ 2.0⋅φ) + 0.122⋅py ⋅pz⋅cos(φ) + 0.012⋅py ⋅pz⋅cos(2.0⋅φ) + 0.01⋅py ⋅pz⋅cos(3.0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                 0.5                          ↪
# ↪              2              2 ⎛  2     2       ⎞                     2 ⎛  2  ↪
# ↪ ⋅φ) + 0.12⋅py ⋅pz - 0.246⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.016⋅py ⋅⎝px   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪              0.5                                          0.5                ↪
# ↪     2       ⎞                         2 ⎛  2     2       ⎞                   ↪
# ↪ + py  - 0.16⎠   ⋅sin(2.0⋅φ) - 0.006⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪         2                   2    2                   2                       ↪
# ↪ .0276⋅py ⋅cos(φ) - 0.0004⋅py ⋅cos (2.0⋅φ) - 0.0418⋅py ⋅cos(2.0⋅φ) + 0.002⋅py ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                       0.5                    ↪
# ↪ 2                       2         4 ⎛  2     2       ⎞                     4 ↪
# ↪  ⋅cos(3.0⋅φ) - 0.0274⋅py  + 0.1⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.005⋅pz  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                      0.5                     ↪
# ↪                       4          3 ⎛  2     2       ⎞                    3 ⎛ ↪
# ↪ ⋅cos(2.0⋅φ) + 0.035⋅pz  + 0.08⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.04⋅pz ⋅⎝ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                  0.5                                                         ↪
# ↪   2     2       ⎞                        3                  3                ↪
# ↪ px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.03⋅pz ⋅cos(φ) + 0.004⋅pz ⋅cos(2.0⋅φ) + 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                               0.5            ↪
# ↪        3                      3           2 ⎛  2     2       ⎞               ↪
# ↪ .002⋅pz ⋅cos(3.0⋅φ) + 0.028⋅pz  - 0.122⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                            0.5                                          0.5  ↪
# ↪        2 ⎛  2     2       ⎞                         2 ⎛  2     2       ⎞     ↪
# ↪ .024⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.002⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                      2                   2    2                   2          ↪
# ↪ sin(3.0⋅φ) + 0.018⋅pz ⋅cos(φ) + 0.0004⋅pz ⋅cos (2.0⋅φ) - 0.0082⋅pz ⋅cos(2.0⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                       0.5    ↪
# ↪               2                       2             ⎛  2     2       ⎞       ↪
# ↪ φ) + 0.0012⋅pz ⋅cos(3.0⋅φ) - 0.0258⋅pz  - 0.0552⋅pz⋅⎝px  + py  - 0.16⎠   ⋅si ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                    0.5                                       ↪
# ↪                  ⎛  2     2       ⎞                           ⎛  2     2     ↪
# ↪ n(φ) - 0.0256⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.0008⋅pz⋅⎝px  + py  - 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪     0.5                                          0.5                         ↪
# ↪    ⎞                           ⎛  2     2       ⎞                            ↪
# ↪ .16⎠   ⋅sin(3.0⋅φ) - 0.0004⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(4.0⋅φ) - 0.01372⋅pz ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                         2                                                    ↪
# ↪ ⋅cos(φ) + 0.00016⋅pz⋅cos (2.0⋅φ) - 0.0036⋅pz⋅cos(2.0⋅φ) - 0.00228⋅pz⋅cos(3.0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                              0.5                             ↪
# ↪                            ⎛  2     2       ⎞                     ⎛  2     2 ↪
# ↪ ⋅φ) - 0.01256⋅pz + 0.02196⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.00576⋅⎝px  + py  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪         0.5                                        0.5                       ↪
# ↪        ⎞                         ⎛  2     2       ⎞                        ⎛ ↪
# ↪  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.00196⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) - 8.0e-5⋅⎝ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                  0.5                                                         ↪
# ↪   2     2       ⎞                                             2              ↪
# ↪ px  + py  - 0.16⎠   ⋅sin(4.0⋅φ) - 0.003224⋅cos(φ) + 8.0e-5⋅cos (2.0⋅φ) + 0.0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________________________________                           ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ 04656⋅cos(2.0⋅φ) - 0.000488⋅cos(3.0⋅φ) - 0.001024  + 75.0⋅pz⋅cos(φ) + 10.0⋅p ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                       __________________     ↪
# ↪                                                      ╱   2     2             ↪
# ↪ z⋅cos(2.0⋅φ) + 5.0⋅pz⋅cos(3.0⋅φ) + 70.0⋅pz - 105.0⋅╲╱  px  + py  - 0.16 ⋅sin ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪               __________________                     __________________      ↪
# ↪              ╱   2     2                            ╱   2     2              ↪
# ↪ (φ) + 20.0⋅╲╱  px  + py  - 0.16 ⋅sin(2.0⋅φ) - 5.0⋅╲╱  px  + py  - 0.16 ⋅sin( ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                    _________________________________________________________ ↪
# ↪                   ╱                                                          ↪
# ↪                  ╱           6          4   2         4   2         4        ↪
# ↪ 3.0⋅φ) - 500.0⋅╲╱   - 0.25⋅px  - 0.75⋅px ⋅py  - 0.5⋅px ⋅pz  - 0.2⋅px ⋅pz⋅cos ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                              0.5                             ↪
# ↪             4            4 ⎛  2     2       ⎞                    4           ↪
# ↪ (φ) - 0.2⋅px ⋅pz + 0.3⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.04⋅px ⋅cos(φ) +  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪         4                      4          2   4     2   2   2         2   2  ↪
# ↪ 0.065⋅px ⋅cos(2.0⋅φ) + 0.265⋅px  - 0.75⋅px ⋅py  - px ⋅py ⋅pz  - 0.4⋅px ⋅py ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                            0.5               ↪
# ↪                   2   2            2   2 ⎛  2     2       ⎞                  ↪
# ↪ pz⋅cos(φ) - 0.4⋅px ⋅py ⋅pz + 0.6⋅px ⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.08 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪    2   2                 2   2                     2   2          2   4      ↪
# ↪ ⋅px ⋅py ⋅cos(φ) + 0.13⋅px ⋅py ⋅cos(2.0⋅φ) + 0.53⋅px ⋅py  - 0.25⋅px ⋅pz  - 0. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                0.5           ↪
# ↪     2   3                2   3         2   2 ⎛  2     2       ⎞              ↪
# ↪ 2⋅px ⋅pz ⋅cos(φ) - 0.2⋅px ⋅pz  + 0.4⋅px ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) -  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪        2   2                 2   2                     2   2          2    ⎛ ↪
# ↪ 0.12⋅px ⋅pz ⋅cos(φ) + 0.03⋅px ⋅pz ⋅cos(2.0⋅φ) + 0.26⋅px ⋅pz  + 0.16⋅px ⋅pz⋅⎝ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                  0.5                                        0.5              ↪
# ↪   2     2       ⎞                    2    ⎛  2     2       ⎞                 ↪
# ↪ px  + py  - 0.16⎠   ⋅sin(φ) + 0.08⋅px ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪          2                     2                        2                    ↪
# ↪  0.122⋅px ⋅pz⋅cos(φ) + 0.012⋅px ⋅pz⋅cos(2.0⋅φ) + 0.01⋅px ⋅pz⋅cos(3.0⋅φ) + 0. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                         0.5                                  ↪
# ↪      2              2 ⎛  2     2       ⎞                     2 ⎛  2     2    ↪
# ↪ 12⋅px ⋅pz - 0.246⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.016⋅px ⋅⎝px  + py  -  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪      0.5                                          0.5                        ↪
# ↪     ⎞                         2 ⎛  2     2       ⎞                           ↪
# ↪ 0.16⎠   ⋅sin(2.0⋅φ) - 0.006⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0276⋅px ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                2 ⎛  2     2  ↪
# ↪                                                     - 1250.0⋅px ⋅⎝px  + py   ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪ 2                   2    2                   2                      2        ↪
# ↪  ⋅cos(φ) - 0.0004⋅px ⋅cos (2.0⋅φ) - 0.0418⋅px ⋅cos(2.0⋅φ) + 0.002⋅px ⋅cos(3. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪        0.5                                                   0.5             ↪
# ↪       ⎞              2                   2 ⎛  2     2       ⎞              2 ↪
# ↪ - 0.16⎠    + 750.0⋅px ⋅sin(φ) - 1250.0⋅py ⋅⎝px  + py  - 0.16⎠    + 750.0⋅py  ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                 2          6         4   2         4                   4     ↪
# ↪ 0⋅φ) - 0.0274⋅px  - 0.25⋅py  - 0.5⋅py ⋅pz  - 0.2⋅py ⋅pz⋅cos(φ) - 0.2⋅py ⋅pz  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                        0.5                                   ↪
# ↪                    2 ⎛  2     2       ⎞              2                   ⎛   ↪
# ↪ ⋅sin(φ) - 1250.0⋅pz ⋅⎝px  + py  - 0.16⎠    + 250.0⋅pz ⋅sin(φ) - 500.0⋅pz⋅⎝px ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                             0.5                                              ↪
# ↪         4 ⎛  2     2       ⎞                    4                  4         ↪
# ↪ + 0.3⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.04⋅py ⋅cos(φ) + 0.065⋅py ⋅cos(2.0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                0.5                                     0.5                   ↪
# ↪ 2     2       ⎞                      ⎛  2     2       ⎞                      ↪
# ↪   + py  - 0.16⎠   ⋅cos(φ) - 500.0⋅pz⋅⎝px  + py  - 0.16⎠    + 100.0⋅pz⋅sin(φ) ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪               4          2   4         2   3                2   3         2  ↪
# ↪ ⋅φ) + 0.265⋅py  - 0.25⋅py ⋅pz  - 0.2⋅py ⋅pz ⋅cos(φ) - 0.2⋅py ⋅pz  + 0.4⋅py ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                 0.5                          ↪
# ↪                               ⎛  2     2       ⎞                  ⎛  2     2 ↪
# ↪  + 50.0⋅pz⋅sin(2.0⋅φ) - 100.0⋅⎝px  + py  - 0.16⎠   ⋅cos(φ) + 50.0⋅⎝px  + py  ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                       0.5                                                    ↪
# ↪   2 ⎛  2     2       ⎞                    2   2                 2   2        ↪
# ↪ pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.12⋅py ⋅pz ⋅cos(φ) + 0.03⋅py ⋅pz ⋅cos(2. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪         0.5                                     0.5                          ↪
# ↪        ⎞                      ⎛  2     2       ⎞                             ↪
# ↪  - 0.16⎠   ⋅cos(2.0⋅φ) + 50.0⋅⎝px  + py  - 0.16⎠    - 100.0⋅sin(φ) + 10.0⋅si ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                     0.5                      ↪
# ↪               2   2          2    ⎛  2     2       ⎞                    2    ↪
# ↪ 0⋅φ) + 0.26⋅py ⋅pz  + 0.16⋅py ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.08⋅py ⋅pz ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ n(2.0⋅φ)                                                                     ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                    0.5                                                       ↪
# ↪  ⎛  2     2       ⎞                         2                     2          ↪
# ↪ ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.122⋅py ⋅pz⋅cos(φ) + 0.012⋅py ⋅pz⋅cos(2 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                            0 ↪
# ↪                2                        2              2 ⎛  2     2       ⎞  ↪
# ↪ .0⋅φ) + 0.01⋅py ⋅pz⋅cos(3.0⋅φ) + 0.12⋅py ⋅pz - 0.246⋅py ⋅⎝px  + py  - 0.16⎠  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪ .5                                      0.5                                  ↪
# ↪                     2 ⎛  2     2       ⎞                         2 ⎛  2      ↪
# ↪   ⋅sin(φ) + 0.016⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) - 0.006⋅py ⋅⎝px  + py ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪          0.5                                                                 ↪
# ↪ 2       ⎞                          2                   2    2                ↪
# ↪   - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0276⋅py ⋅cos(φ) - 0.0004⋅py ⋅cos (2.0⋅φ) - 0.041 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪     2                      2                       2         4 ⎛  2     2    ↪
# ↪ 8⋅py ⋅cos(2.0⋅φ) + 0.002⋅py ⋅cos(3.0⋅φ) - 0.0274⋅py  + 0.1⋅pz ⋅⎝px  + py  -  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪      0.5                                                                     ↪
# ↪     ⎞                     4                      4          3 ⎛  2     2     ↪
# ↪ 0.16⎠   ⋅sin(φ) + 0.005⋅pz ⋅cos(2.0⋅φ) + 0.035⋅pz  + 0.08⋅pz ⋅⎝px  + py  - 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪     0.5                                     0.5                              ↪
# ↪    ⎞                    3 ⎛  2     2       ⎞                        3        ↪
# ↪ .16⎠   ⋅sin(φ) + 0.04⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.03⋅pz ⋅cos(φ) ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪            3                      3                      3           2 ⎛  2  ↪
# ↪  + 0.004⋅pz ⋅cos(2.0⋅φ) + 0.002⋅pz ⋅cos(3.0⋅φ) + 0.028⋅pz  - 0.122⋅pz ⋅⎝px   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪              0.5                                      0.5                    ↪
# ↪     2       ⎞                     2 ⎛  2     2       ⎞                       ↪
# ↪ + py  - 0.16⎠   ⋅sin(φ) + 0.024⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.002 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                        0.5                                                   ↪
# ↪    2 ⎛  2     2       ⎞                         2                   2    2   ↪
# ↪ ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.018⋅pz ⋅cos(φ) + 0.0004⋅pz ⋅cos (2 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                  2                       2                       2           ↪
# ↪ .0⋅φ) - 0.0082⋅pz ⋅cos(2.0⋅φ) + 0.0012⋅pz ⋅cos(3.0⋅φ) - 0.0258⋅pz  - 0.0552⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                      0.5                                      0.5            ↪
# ↪    ⎛  2     2       ⎞                       ⎛  2     2       ⎞               ↪
# ↪ pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.0256⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ...
# ↪ 2     2       ⎞                          2                   2    2          ↪
# ↪   + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0276⋅px ⋅cos(φ) - 0.0004⋅px ⋅cos (2.0⋅φ) - ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪           2                      2                       2          6        ↪
# ↪  0.0418⋅px ⋅cos(2.0⋅φ) + 0.002⋅px ⋅cos(3.0⋅φ) - 0.0274⋅px  - 0.25⋅py  - 0.5⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                      0.5     ↪
# ↪   4   2         4                   4            4 ⎛  2     2       ⎞        ↪
# ↪ py ⋅pz  - 0.2⋅py ⋅pz⋅cos(φ) - 0.2⋅py ⋅pz + 0.3⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪              4                  4                      4          2   4      ↪
# ↪ (φ) - 0.04⋅py ⋅cos(φ) + 0.065⋅py ⋅cos(2.0⋅φ) + 0.265⋅py  - 0.25⋅py ⋅pz  - 0. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                0.5           ↪
# ↪     2   3                2   3         2   2 ⎛  2     2       ⎞              ↪
# ↪ 2⋅py ⋅pz ⋅cos(φ) - 0.2⋅py ⋅pz  + 0.4⋅py ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) -  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                 2           2           2    ↪
# ↪                                         250.0⋅px  + 250.0⋅py  + 250.0⋅pz  +  ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪        2   2                 2   2                     2   2          2    ⎛ ↪
# ↪ 0.12⋅py ⋅pz ⋅cos(φ) + 0.03⋅py ⋅pz ⋅cos(2.0⋅φ) + 0.26⋅py ⋅pz  + 0.16⋅py ⋅pz⋅⎝ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                      0.5                     ↪
# ↪                                    ⎛  2     2       ⎞                        ↪
# ↪ 100.0⋅pz⋅cos(φ) + 100.0⋅pz - 100.0⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 20.0⋅cos(φ ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                  0.5                                        0.5              ↪
# ↪   2     2       ⎞                    2    ⎛  2     2       ⎞                 ↪
# ↪ px  + py  - 0.16⎠   ⋅sin(φ) + 0.08⋅py ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ) - 20.0                                                                     ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪          2                     2                        2                    ↪
# ↪  0.122⋅py ⋅pz⋅cos(φ) + 0.012⋅py ⋅pz⋅cos(2.0⋅φ) + 0.01⋅py ⋅pz⋅cos(3.0⋅φ) + 0. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                         0.5                                  ↪
# ↪      2              2 ⎛  2     2       ⎞                     2 ⎛  2     2    ↪
# ↪ 12⋅py ⋅pz - 0.246⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.016⋅py ⋅⎝px  + py  -  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪      0.5                                          0.5                        ↪
# ↪     ⎞                         2 ⎛  2     2       ⎞                           ↪
# ↪ 0.16⎠   ⋅sin(2.0⋅φ) - 0.006⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0276⋅py ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪ 2                   2    2                   2                      2        ↪
# ↪  ⋅cos(φ) - 0.0004⋅py ⋅cos (2.0⋅φ) - 0.0418⋅py ⋅cos(2.0⋅φ) + 0.002⋅py ⋅cos(3. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                               0.5                            ↪
# ↪                 2         4 ⎛  2     2       ⎞                     4         ↪
# ↪ 0⋅φ) - 0.0274⋅py  + 0.1⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.005⋅pz ⋅cos(2.0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                              0.5                             ↪
# ↪               4          3 ⎛  2     2       ⎞                    3 ⎛  2      ↪
# ↪ ⋅φ) + 0.035⋅pz  + 0.08⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.04⋅pz ⋅⎝px  + py ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪          0.5                                                                 ↪
# ↪ 2       ⎞                        3                  3                      3 ↪
# ↪   - 0.16⎠   ⋅sin(2.0⋅φ) + 0.03⋅pz ⋅cos(φ) + 0.004⋅pz ⋅cos(2.0⋅φ) + 0.002⋅pz  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                       0.5                    ↪
# ↪                       3           2 ⎛  2     2       ⎞                     2 ↪
# ↪ ⋅cos(3.0⋅φ) + 0.028⋅pz  - 0.122⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.024⋅pz  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                    0.5                                          0.5          ↪
# ↪  ⎛  2     2       ⎞                         2 ⎛  2     2       ⎞             ↪
# ↪ ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.002⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪              2                   2    2                   2                  ↪
# ↪ φ) + 0.018⋅pz ⋅cos(φ) + 0.0004⋅pz ⋅cos (2.0⋅φ) - 0.0082⋅pz ⋅cos(2.0⋅φ) + 0.0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                               0.5            ↪
# ↪       2                       2             ⎛  2     2       ⎞               ↪
# ↪ 012⋅pz ⋅cos(3.0⋅φ) - 0.0258⋅pz  - 0.0552⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                            0.5                                          0.5  ↪
# ↪          ⎛  2     2       ⎞                           ⎛  2     2       ⎞     ↪
# ↪ .0256⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.0008⋅pz⋅⎝px  + py  - 0.16⎠   ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                          0.5                                 ↪
# ↪                        ⎛  2     2       ⎞                                    ↪
# ↪ sin(3.0⋅φ) - 0.0004⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(4.0⋅φ) - 0.01372⋅pz⋅cos(φ)  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                 2                                                            ↪
# ↪ + 0.00016⋅pz⋅cos (2.0⋅φ) - 0.0036⋅pz⋅cos(2.0⋅φ) - 0.00228⋅pz⋅cos(3.0⋅φ) - 0. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                      0.5                                     ↪
# ↪                    ⎛  2     2       ⎞                     ⎛  2     2       ⎞ ↪
# ↪ 01256⋅pz + 0.02196⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.00576⋅⎝px  + py  - 0.16⎠ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪ 0.5                                        0.5                               ↪
# ↪                          ⎛  2     2       ⎞                        ⎛  2      ↪
# ↪    ⋅sin(2.0⋅φ) + 0.00196⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) - 8.0e-5⋅⎝px  + py ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪          0.5                                                                 ↪
# ↪ 2       ⎞                                             2                      ↪
# ↪   - 0.16⎠   ⋅sin(4.0⋅φ) - 0.003224⋅cos(φ) + 8.0e-5⋅cos (2.0⋅φ) + 0.004656⋅co ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________________________                       ⎞⎤
# ↪                                                                  ⎟⎥
# ↪                                                                  ⎟⎥
# ↪ s(2.0⋅φ) - 0.000488⋅cos(3.0⋅φ) - 0.001024  + 2.0⋅cos(2.0⋅φ) - 2.0⎟⎥
# ↪ ─────────────────────────────────────────────────────────────────⎟⎥
# ↪                                                                  ⎟⎥
# ↪                                                                  ⎟⎥
# ↪                                                                  ⎠⎦
