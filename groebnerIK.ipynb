# %%
import sympy as sp

# Geometric parameters for the legs (constants for a real robot, but slow computation if symbolic)
a0 = 0
a1 = 0.4
a2 = 0.5
a3 = 0.5
a4 = 0.2
d1 = 0.2

# Define symbols for the leg
px, py, pz, q1, q2, q3, q4, s1, c1, s2, c2, s23, c23, phi = sp.symbols(
    'px py pz q1 q2 q3 q4 s1 c1 s2 c2 s23 c23 phi'
)

# Polynomials (Forward Kinematics)
H = sp.sqrt((px + a0)**2 + py**2 - a1**2) - a2 * c2 - a3 * c23 - a4 * sp.sin(phi)
poly1 = -a0 - a1 * c1 + sp.sqrt((px + a0)**2 + py**2 - a1**2) * s1 - px
poly2 = a1 * s1 + sp.sqrt((px + a0)**2 + py**2 - a1**2) * c1 + py
poly3 = -d1 + a2 * s2 + a3 * s23 - a4 * sp.cos(phi) - pz

# Trigonometric identities
id2 = s2**2 + c2**2 - 1
id23 = s23**2 + c23**2 - 1

# Gröbner bases
# Basis 1: Variables [s1, c1]
polys1 = [poly1, poly2]
vars1 = [s1, c1]
gbase1 = sp.groebner(polys1, *vars1, order='grevlex')

# Basis 2: Variables [c2, s2, c23, s23]
polys2 = [H, poly3, id2, id23]
vars2 = [s2, c2, s23, c23]
gbase2 = sp.groebner(polys2, *vars2, order='grevlex')

# Simplify Gröbner bases
gbase1_simplified = [sp.simplify(poly) for poly in gbase1]
gbase2_simplified = [sp.simplify(poly) for poly in gbase2]

# %%
# Symbolic solutions for q1:

# Solve for s1 from the first polynomial in gbase1_simplified
s1_solution = sp.solve(gbase1_simplified[0], s1)

# Compute q1 using asin (arcsin) of s1 solutions
q1 = sp.asin(s1_solution[0])

# %%
# Symbolic solutions for q2 and q3:

# Solve for s23 from the first polynomial in gbase2_simplified
c23_solutions = sp.solve(gbase2_simplified[0], c23)

# Compute q2 and q3 based on c23_solutions[0]
s2_solutions_1 = sp.solve(gbase2_simplified[1].subs(c23, c23_solutions[0]), s2)
q2_1 = sp.asin(s2_solutions_1[0])
q23_1 = sp.acos(c23_solutions[0])
q3_1 = q23_1 - q2_1
q4_1 = -q3_1 - q2_1 + phi

# Compute q2 and q3 based on c23_solutions[1]
s2_solutions_2 = sp.solve(gbase2_simplified[1].subs(c23, c23_solutions[1]), s2)
q2_2 = sp.asin(s2_solutions_1[0])
q23_2 = sp.acos(c23_solutions[1])
q3_2 = q23_2 - q2_2
q4_2 = -q3_2 - q2_2 + phi

# %%
sp.pprint([q1, q2_1, q3_1, q4_1])
# Out:
# ⎡                                                                              ↪
# ⎢    ⎛     ⎛                                             __________________⎞⎞  ↪
# ⎢    ⎜     ⎜       3             2                      ╱   2     2        ⎟⎟  ↪
# ⎢    ⎜0.04⋅⎝25.0⋅px  + 25.0⋅px⋅py  - 4.0⋅px - 10.0⋅py⋅╲╱  px  + py  - 0.16 ⎠⎟  ↪
# ⎢asin⎜──────────────────────────────────────────────────────────────────────⎟, ↪
# ⎢    ⎜                                 __________________                   ⎟  ↪
# ⎢    ⎜                  ⎛  2     2⎞   ╱   2     2                           ⎟  ↪
# ⎣    ⎝                  ⎝px  + py ⎠⋅╲╱  px  + py  - 0.16                    ⎠  ↪
#
# ↪      ⎛                                                                       ↪
# ↪      ⎜                                                                       ↪
# ↪      ⎜              4   2                4                          4        ↪
# ↪      ⎜3.90625e+18⋅px ⋅pz  + 1.5625e+18⋅px ⋅pz⋅cos(φ) + 1.5625e+18⋅px ⋅pz + 3 ↪
# ↪  asin⎜────────────────────────────────────────────────────────────────────── ↪
# ↪      ⎜                                                                       ↪
# ↪      ⎜                                                                       ↪
# ↪      ⎝                                                                       ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪            4                       4                            4            ↪
# ↪ .125e+17⋅px ⋅cos(φ) + 7.8125e+16⋅px ⋅cos(2.0⋅φ) + 2.34375e+17⋅px  + 7.8125e+ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪      2   2   2               2   2                         2   2             ↪
# ↪ 18⋅px ⋅py ⋅pz  + 3.125e+18⋅px ⋅py ⋅pz⋅cos(φ) + 3.125e+18⋅px ⋅py ⋅pz + 6.25e+ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪      2   2                       2   2                           2   2       ↪
# ↪ 17⋅px ⋅py ⋅cos(φ) + 1.5625e+17⋅px ⋅py ⋅cos(2.0⋅φ) + 4.6875e+17⋅px ⋅py  + 7.8 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪           2   4              2   3                     2   3               2 ↪
# ↪ 125e+18⋅px ⋅pz  + 6.25e+18⋅px ⋅pz ⋅cos(φ) + 6.25e+18⋅px ⋅pz  - 3.125e+18⋅px  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪         __________________                                                   ↪
# ↪    2   ╱   2     2                             2   2                       2 ↪
# ↪ ⋅pz ⋅╲╱  px  + py  - 0.16 ⋅sin(φ) + 3.75e+18⋅px ⋅pz ⋅cos(φ) + 4.6875e+17⋅px  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                            _________________ ↪
# ↪    2                            2   2              2      ╱   2     2        ↪
# ↪ ⋅pz ⋅cos(2.0⋅φ) + 2.03125e+18⋅px ⋅pz  - 1.25e+18⋅px ⋅pz⋅╲╱  px  + py  - 0.16 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ _                             __________________                             ↪
# ↪                       2      ╱   2     2                                   2 ↪
# ↪  ⋅sin(φ) - 6.25e+17⋅px ⋅pz⋅╲╱  px  + py  - 0.16 ⋅sin(2.0⋅φ) + 5.3125e+17⋅px  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                          2                             2                     ↪
# ↪ ⋅pz⋅cos(φ) + 1.875e+17⋅px ⋅pz⋅cos(2.0⋅φ) - 3.125e+16⋅px ⋅pz⋅cos(3.0⋅φ) + 3.1 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                    _________ ↪
# ↪                                             __________________    ╱          ↪
# ↪          2                             2   ╱   2     2           ╱           ↪
# ↪ 25e+17⋅px ⋅pz - 5.52427172801991e+18⋅px ⋅╲╱  px  + py  - 0.16 ⋅╲╱   - 0.5⋅px ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪ 4   2         4                   4             4                 4          ↪
# ↪  ⋅pz  - 0.2⋅px ⋅pz⋅cos(φ) - 0.2⋅px ⋅pz - 0.04⋅px ⋅cos(φ) - 0.01⋅px ⋅cos(2.0⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪             4     2   2   2         2   2                   2   2            ↪
# ↪ φ) - 0.03⋅px  - px ⋅py ⋅pz  - 0.4⋅px ⋅py ⋅pz⋅cos(φ) - 0.4⋅px ⋅py ⋅pz - 0.08⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪   2   2                 2   2                     2   2     2   4         2  ↪
# ↪ px ⋅py ⋅cos(φ) - 0.02⋅px ⋅py ⋅cos(2.0⋅φ) - 0.06⋅px ⋅py  - px ⋅pz  - 0.8⋅px ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                          0.5                 ↪
# ↪   3                2   3         2   2 ⎛  2     2       ⎞                    ↪
# ↪ pz ⋅cos(φ) - 0.8⋅px ⋅pz  + 0.4⋅px ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.48⋅p ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪  2   2                 2   2                     2   2          2    ⎛  2    ↪
# ↪ x ⋅pz ⋅cos(φ) - 0.06⋅px ⋅pz ⋅cos(2.0⋅φ) + 0.24⋅px ⋅pz  + 0.16⋅px ⋅pz⋅⎝px  +  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪            0.5                                        0.5                    ↪
# ↪   2       ⎞                    2    ⎛  2     2       ⎞                       ↪
# ↪ py  - 0.16⎠   ⋅sin(φ) + 0.08⋅px ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.132 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪    2                     2                         2                         ↪
# ↪ ⋅px ⋅pz⋅cos(φ) - 0.024⋅px ⋅pz⋅cos(2.0⋅φ) + 0.004⋅px ⋅pz⋅cos(3.0⋅φ) + 0.16⋅px ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                   0.5                                      0 ↪
# ↪ 2             2 ⎛  2     2       ⎞                     2 ⎛  2     2       ⎞  ↪
# ↪  ⋅pz + 0.02⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.016⋅px ⋅⎝px  + py  - 0.16⎠  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪ .5                                          0.5                              ↪
# ↪                         2 ⎛  2     2       ⎞                          2      ↪
# ↪   ⋅sin(2.0⋅φ) + 0.004⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0392⋅px ⋅cos( ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪               2    2                 2                       2               ↪
# ↪ φ) + 0.0008⋅px ⋅cos (2.0⋅φ) + 0.01⋅px ⋅cos(2.0⋅φ) + 0.0008⋅px ⋅cos(3.0⋅φ) +  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪          2         4   2         4                   4             4         ↪
# ↪ 0.0292⋅px  - 0.5⋅py ⋅pz  - 0.2⋅py ⋅pz⋅cos(φ) - 0.2⋅py ⋅pz - 0.04⋅py ⋅cos(φ)  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪          4                     4     2   4         2   3                2    ↪
# ↪ - 0.01⋅py ⋅cos(2.0⋅φ) - 0.03⋅py  - py ⋅pz  - 0.8⋅py ⋅pz ⋅cos(φ) - 0.8⋅py ⋅pz ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                   0.5                                        ↪
# ↪ 3         2   2 ⎛  2     2       ⎞                    2   2                  ↪
# ↪   + 0.4⋅py ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.48⋅py ⋅pz ⋅cos(φ) - 0.06⋅py ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                 0.5          ↪
# ↪ 2   2                     2   2          2    ⎛  2     2       ⎞             ↪
# ↪  ⋅pz ⋅cos(2.0⋅φ) + 0.24⋅py ⋅pz  + 0.16⋅py ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                0.5                                           ↪
# ↪         2    ⎛  2     2       ⎞                         2                    ↪
# ↪  0.08⋅py ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.132⋅py ⋅pz⋅cos(φ) - 0.024⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪   2                         2                        2             2 ⎛  2    ↪
# ↪ py ⋅pz⋅cos(2.0⋅φ) + 0.004⋅py ⋅pz⋅cos(3.0⋅φ) + 0.16⋅py ⋅pz + 0.02⋅py ⋅⎝px  +  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪            0.5                                      0.5                      ↪
# ↪   2       ⎞                     2 ⎛  2     2       ⎞                         ↪
# ↪ py  - 0.16⎠   ⋅sin(φ) + 0.016⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.004⋅p ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                      0.5                                                     ↪
# ↪  2 ⎛  2     2       ⎞                          2                   2    2    ↪
# ↪ y ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0392⋅py ⋅cos(φ) + 0.0008⋅py ⋅cos (2. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪               2                       2                       2         6    ↪
# ↪ 0⋅φ) + 0.01⋅py ⋅cos(2.0⋅φ) + 0.0008⋅py ⋅cos(3.0⋅φ) + 0.0292⋅py  - 0.5⋅pz  -  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                      0.5                     ↪
# ↪       5                5         4 ⎛  2     2       ⎞                   4    ↪
# ↪ 0.6⋅pz ⋅cos(φ) - 0.6⋅pz  + 0.4⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.6⋅pz ⋅co ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                    0.5       ↪
# ↪               4                     4          3 ⎛  2     2       ⎞          ↪
# ↪ s(φ) - 0.13⋅pz ⋅cos(2.0⋅φ) + 0.19⋅pz  + 0.32⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                0.5                                           ↪
# ↪            3 ⎛  2     2       ⎞                        3                  3  ↪
# ↪ ) + 0.16⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.22⋅pz ⋅cos(φ) - 0.104⋅pz ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                      3                      3           2 ⎛  2     2       ⎞ ↪
# ↪ cos(2.0⋅φ) - 0.012⋅pz ⋅cos(3.0⋅φ) + 0.312⋅pz  - 0.132⋅pz ⋅⎝px  + py  - 0.16⎠ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪ 0.5                                      0.5                                 ↪
# ↪                      2 ⎛  2     2       ⎞                        2 ⎛  2      ↪
# ↪    ⋅sin(φ) + 0.096⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.02⋅pz ⋅⎝px  + py ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪          0.5                                                                 ↪
# ↪ 2       ⎞                         2                   2    2                 ↪
# ↪   - 0.16⎠   ⋅sin(3.0⋅φ) + 0.228⋅pz ⋅cos(φ) - 0.0008⋅pz ⋅cos (2.0⋅φ) + 0.0228 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪    2                       2                      2             ⎛  2     2   ↪
# ↪ ⋅pz ⋅cos(2.0⋅φ) - 0.0072⋅pz ⋅cos(3.0⋅φ) + 0.106⋅pz  - 0.0784⋅pz⋅⎝px  + py  - ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪       0.5                                      0.5                           ↪
# ↪      ⎞                       ⎛  2     2       ⎞                          ⎛   ↪
# ↪  0.16⎠   ⋅sin(φ) - 0.0288⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.008⋅pz⋅⎝px ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                0.5                                          0.5              ↪
# ↪ 2     2       ⎞                           ⎛  2     2       ⎞                 ↪
# ↪   + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0008⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(4.0⋅φ) + ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                    2                                         ↪
# ↪  0.03224⋅pz⋅cos(φ) - 0.00032⋅pz⋅cos (2.0⋅φ) + 0.01744⋅pz⋅cos(2.0⋅φ) - 0.0002 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                          0.5                 ↪
# ↪                                        ⎛  2     2       ⎞                    ↪
# ↪ 4⋅pz⋅cos(3.0⋅φ) + 0.01488⋅pz - 0.01096⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.0083 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                     0.5                                        0.5           ↪
# ↪   ⎛  2     2       ⎞                         ⎛  2     2       ⎞              ↪
# ↪ 2⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) - 0.00168⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                               0.5                                            ↪
# ↪             ⎛  2     2       ⎞                                               ↪
# ↪ ) + 0.00016⋅⎝px  + py  - 0.16⎠   ⋅sin(4.0⋅φ) - 0.000144⋅cos(φ) - 0.00016⋅cos ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ________________________________________________________________             ↪
# ↪                                                                              ↪
# ↪ 2                                                                            ↪
# ↪  (2.0⋅φ) + 0.000608⋅cos(2.0⋅φ) + 0.000144⋅cos(3.0⋅φ) - 0.000448  - 1.5625e+1 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪          __________________                          __________________      ↪
# ↪     2   ╱   2     2                             2   ╱   2     2              ↪
# ↪ 7⋅px ⋅╲╱  px  + py  - 0.16 ⋅sin(φ) - 1.25e+17⋅px ⋅╲╱  px  + py  - 0.16 ⋅sin( ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                           __________________                                 ↪
# ↪                      2   ╱   2     2                                         ↪
# ↪ 2.0⋅φ) - 3.125e+16⋅px ⋅╲╱  px  + py  - 0.16 ⋅sin(3.0⋅φ) + 3.31456303681194e+ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪            _________________________________________________________________ ↪
# ↪           ╱                                                                  ↪
# ↪      2   ╱          4   2         4                   4             4        ↪
# ↪ 18⋅px ⋅╲╱   - 0.5⋅px ⋅pz  - 0.2⋅px ⋅pz⋅cos(φ) - 0.2⋅px ⋅pz - 0.04⋅px ⋅cos(φ) ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪           4                     4     2   2   2         2   2                ↪
# ↪  - 0.01⋅px ⋅cos(2.0⋅φ) - 0.03⋅px  - px ⋅py ⋅pz  - 0.4⋅px ⋅py ⋅pz⋅cos(φ) - 0. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪     2   2             2   2                 2   2                     2   2  ↪
# ↪ 4⋅px ⋅py ⋅pz - 0.08⋅px ⋅py ⋅cos(φ) - 0.02⋅px ⋅py ⋅cos(2.0⋅φ) - 0.06⋅px ⋅py   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪     2   4         2   3                2   3         2   2 ⎛  2     2        ↪
# ↪ - px ⋅pz  - 0.8⋅px ⋅pz ⋅cos(φ) - 0.8⋅px ⋅pz  + 0.4⋅px ⋅pz ⋅⎝px  + py  - 0.16 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪  0.5                                                                         ↪
# ↪ ⎞                    2   2                 2   2                     2   2   ↪
# ↪ ⎠   ⋅sin(φ) - 0.48⋅px ⋅pz ⋅cos(φ) - 0.06⋅px ⋅pz ⋅cos(2.0⋅φ) + 0.24⋅px ⋅pz  + ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                0.5                                        0. ↪
# ↪         2    ⎛  2     2       ⎞                    2    ⎛  2     2       ⎞   ↪
# ↪  0.16⋅px ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.08⋅px ⋅pz⋅⎝px  + py  - 0.16⎠   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪ 5                                                                            ↪
# ↪                        2                     2                         2     ↪
# ↪  ⋅sin(2.0⋅φ) + 0.132⋅px ⋅pz⋅cos(φ) - 0.024⋅px ⋅pz⋅cos(2.0⋅φ) + 0.004⋅px ⋅pz⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                       0.5                    ↪
# ↪                     2             2 ⎛  2     2       ⎞                     2 ↪
# ↪ cos(3.0⋅φ) + 0.16⋅px ⋅pz + 0.02⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.016⋅px  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                    0.5                                          0.5          ↪
# ↪  ⎛  2     2       ⎞                         2 ⎛  2     2       ⎞             ↪
# ↪ ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.004⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪               2                   2    2                 2                   ↪
# ↪ φ) + 0.0392⋅px ⋅cos(φ) + 0.0008⋅px ⋅cos (2.0⋅φ) + 0.01⋅px ⋅cos(2.0⋅φ) + 0.00 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪      2                       2         4   2         4                   4   ↪
# ↪ 08⋅px ⋅cos(3.0⋅φ) + 0.0292⋅px  - 0.5⋅py ⋅pz  - 0.2⋅py ⋅pz⋅cos(φ) - 0.2⋅py ⋅p ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪            4                 4                     4     2   4         2   3 ↪
# ↪ z - 0.04⋅py ⋅cos(φ) - 0.01⋅py ⋅cos(2.0⋅φ) - 0.03⋅py  - py ⋅pz  - 0.8⋅py ⋅pz  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                       0.5                    ↪
# ↪                 2   3         2   2 ⎛  2     2       ⎞                    2  ↪
# ↪ ⋅cos(φ) - 0.8⋅py ⋅pz  + 0.4⋅py ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.48⋅py ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪   2                 2   2                     2   2          2    ⎛  2     2 ↪
# ↪ pz ⋅cos(φ) - 0.06⋅py ⋅pz ⋅cos(2.0⋅φ) + 0.24⋅py ⋅pz  + 0.16⋅py ⋅pz⋅⎝px  + py  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪         0.5                                        0.5                       ↪
# ↪        ⎞                    2    ⎛  2     2       ⎞                          ↪
# ↪  - 0.16⎠   ⋅sin(φ) + 0.08⋅py ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.132⋅py ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪ 2                     2                         2                        2   ↪
# ↪  ⋅pz⋅cos(φ) - 0.024⋅py ⋅pz⋅cos(2.0⋅φ) + 0.004⋅py ⋅pz⋅cos(3.0⋅φ) + 0.16⋅py ⋅p ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                0.5                                      0.5  ↪
# ↪            2 ⎛  2     2       ⎞                     2 ⎛  2     2       ⎞     ↪
# ↪ z + 0.02⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.016⋅py ⋅⎝px  + py  - 0.16⎠   ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                          0.5                                 ↪
# ↪                      2 ⎛  2     2       ⎞                          2         ↪
# ↪ sin(2.0⋅φ) + 0.004⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0392⋅py ⋅cos(φ)  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪            2    2                 2                       2                  ↪
# ↪ + 0.0008⋅py ⋅cos (2.0⋅φ) + 0.01⋅py ⋅cos(2.0⋅φ) + 0.0008⋅py ⋅cos(3.0⋅φ) + 0.0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                          0.5 ↪
# ↪       2         6         5                5         4 ⎛  2     2       ⎞    ↪
# ↪ 292⋅py  - 0.5⋅pz  - 0.6⋅pz ⋅cos(φ) - 0.6⋅pz  + 0.4⋅pz ⋅⎝px  + py  - 0.16⎠    ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                 4                 4                     4          3 ⎛  2    ↪
# ↪ ⋅sin(φ) - 0.6⋅pz ⋅cos(φ) - 0.13⋅pz ⋅cos(2.0⋅φ) + 0.19⋅pz  + 0.32⋅pz ⋅⎝px  +  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪            0.5                                     0.5                       ↪
# ↪   2       ⎞                    3 ⎛  2     2       ⎞                        3 ↪
# ↪ py  - 0.16⎠   ⋅sin(φ) + 0.16⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.22⋅pz  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                   3                      3                      3            ↪
# ↪ ⋅cos(φ) - 0.104⋅pz ⋅cos(2.0⋅φ) - 0.012⋅pz ⋅cos(3.0⋅φ) + 0.312⋅pz  - 0.132⋅pz ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                     0.5                                      0.5             ↪
# ↪ 2 ⎛  2     2       ⎞                     2 ⎛  2     2       ⎞                ↪
# ↪  ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.096⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ)  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                              0.5                                             ↪
# ↪          2 ⎛  2     2       ⎞                         2                   2  ↪
# ↪ + 0.02⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.228⋅pz ⋅cos(φ) - 0.0008⋅pz ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪    2                   2                       2                      2      ↪
# ↪ cos (2.0⋅φ) + 0.0228⋅pz ⋅cos(2.0⋅φ) - 0.0072⋅pz ⋅cos(3.0⋅φ) + 0.106⋅pz  - 0. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                           0.5                                      0.5       ↪
# ↪         ⎛  2     2       ⎞                       ⎛  2     2       ⎞          ↪
# ↪ 0784⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.0288⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                    0.5                                       ↪
# ↪                  ⎛  2     2       ⎞                           ⎛  2     2     ↪
# ↪ .0⋅φ) + 0.008⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0008⋅pz⋅⎝px  + py  - 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ...
# ↪      2       ⎞                          2                   2    2           ↪
# ↪  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0392⋅px ⋅cos(φ) + 0.0008⋅px ⋅cos (2.0⋅φ) +  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪        2                       2                       2         4   2       ↪
# ↪ 0.01⋅px ⋅cos(2.0⋅φ) + 0.0008⋅px ⋅cos(3.0⋅φ) + 0.0292⋅px  - 0.5⋅py ⋅pz  - 0.2 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪    4                   4             4                 4                     ↪
# ↪ ⋅py ⋅pz⋅cos(φ) - 0.2⋅py ⋅pz - 0.04⋅py ⋅cos(φ) - 0.01⋅py ⋅cos(2.0⋅φ) - 0.03⋅p ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪  4     2   4         2   3                2   3         2   2 ⎛  2     2     ↪
# ↪ y  - py ⋅pz  - 0.8⋅py ⋅pz ⋅cos(φ) - 0.8⋅py ⋅pz  + 0.4⋅py ⋅pz ⋅⎝px  + py  - 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪     0.5                                                                      ↪
# ↪    ⎞                    2   2                 2   2                     2    ↪
# ↪ .16⎠   ⋅sin(φ) - 0.48⋅py ⋅pz ⋅cos(φ) - 0.06⋅py ⋅pz ⋅cos(2.0⋅φ) + 0.24⋅py ⋅pz ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                    2         ↪
# ↪                                                            250.0⋅px  + 250.0 ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                   0.5                                        ↪
# ↪ 2          2    ⎛  2     2       ⎞                    2    ⎛  2     2        ↪
# ↪   + 0.16⋅py ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.08⋅py ⋅pz⋅⎝px  + py  - 0.16 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                         0.5  ↪
# ↪    2           2                                      ⎛  2     2       ⎞     ↪
# ↪ ⋅py  + 250.0⋅pz  + 100.0⋅pz⋅cos(φ) + 100.0⋅pz - 100.0⋅⎝px  + py  - 0.16⎠   ⋅ ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪  0.5                                                                         ↪
# ↪ ⎞                         2                     2                         2  ↪
# ↪ ⎠   ⋅sin(2.0⋅φ) + 0.132⋅py ⋅pz⋅cos(φ) - 0.024⋅py ⋅pz⋅cos(2.0⋅φ) + 0.004⋅py ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ sin(φ) + 20.0⋅cos(φ) - 20.0                                                  ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                          0.5                 ↪
# ↪                        2             2 ⎛  2     2       ⎞                    ↪
# ↪ pz⋅cos(3.0⋅φ) + 0.16⋅py ⋅pz + 0.02⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.016⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                       0.5                                          0.5       ↪
# ↪   2 ⎛  2     2       ⎞                         2 ⎛  2     2       ⎞          ↪
# ↪ py ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.004⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(3 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                  2                   2    2                 2                ↪
# ↪ .0⋅φ) + 0.0392⋅py ⋅cos(φ) + 0.0008⋅py ⋅cos (2.0⋅φ) + 0.01⋅py ⋅cos(2.0⋅φ) + 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪         2                       2         6         5                5       ↪
# ↪ .0008⋅py ⋅cos(3.0⋅φ) + 0.0292⋅py  - 0.5⋅pz  - 0.6⋅pz ⋅cos(φ) - 0.6⋅pz  + 0.4 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                        0.5                                                   ↪
# ↪    4 ⎛  2     2       ⎞                   4                 4                ↪
# ↪ ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.6⋅pz ⋅cos(φ) - 0.13⋅pz ⋅cos(2.0⋅φ) + 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                      0.5                                     ↪
# ↪       4          3 ⎛  2     2       ⎞                    3 ⎛  2     2        ↪
# ↪ .19⋅pz  + 0.32⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.16⋅pz ⋅⎝px  + py  - 0.16 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪  0.5                                                                         ↪
# ↪ ⎞                        3                  3                      3         ↪
# ↪ ⎠   ⋅sin(2.0⋅φ) + 0.22⋅pz ⋅cos(φ) - 0.104⋅pz ⋅cos(2.0⋅φ) - 0.012⋅pz ⋅cos(3.0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                               0.5                            ↪
# ↪               3           2 ⎛  2     2       ⎞                     2 ⎛  2    ↪
# ↪ ⋅φ) + 0.312⋅pz  - 0.132⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.096⋅pz ⋅⎝px  +  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪            0.5                                         0.5                   ↪
# ↪   2       ⎞                        2 ⎛  2     2       ⎞                      ↪
# ↪ py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.02⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.22 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪     2                   2    2                   2                       2   ↪
# ↪ 8⋅pz ⋅cos(φ) - 0.0008⋅pz ⋅cos (2.0⋅φ) + 0.0228⋅pz ⋅cos(2.0⋅φ) - 0.0072⋅pz ⋅c ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                     0.5                      ↪
# ↪                     2             ⎛  2     2       ⎞                       ⎛ ↪
# ↪ os(3.0⋅φ) + 0.106⋅pz  - 0.0784⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.0288⋅pz⋅⎝ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                  0.5                                         0.5             ↪
# ↪   2     2       ⎞                          ⎛  2     2       ⎞                ↪
# ↪ px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.008⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ)  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                               0.5                                            ↪
# ↪             ⎛  2     2       ⎞                                               ↪
# ↪ + 0.0008⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(4.0⋅φ) + 0.03224⋅pz⋅cos(φ) - 0.00032⋅p ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪      2                                                                       ↪
# ↪ z⋅cos (2.0⋅φ) + 0.01744⋅pz⋅cos(2.0⋅φ) - 0.00024⋅pz⋅cos(3.0⋅φ) + 0.01488⋅pz - ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                            0.5                                    0.5        ↪
# ↪          ⎛  2     2       ⎞                     ⎛  2     2       ⎞           ↪
# ↪  0.01096⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.00832⋅⎝px  + py  - 0.16⎠   ⋅sin(2. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                  0.5                                         ↪
# ↪                ⎛  2     2       ⎞                         ⎛  2     2       ⎞ ↪
# ↪ 0⋅φ) - 0.00168⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.00016⋅⎝px  + py  - 0.16⎠ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪ 0.5                                                                          ↪
# ↪                                               2                              ↪
# ↪    ⋅sin(4.0⋅φ) - 0.000144⋅cos(φ) - 0.00016⋅cos (2.0⋅φ) + 0.000608⋅cos(2.0⋅φ) ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________________                               ⎞⎤
# ↪                                                                  ⎟⎥
# ↪                                                                  ⎟⎥
# ↪  + 0.000144⋅cos(3.0⋅φ) - 0.000448  + 20.0⋅sin(φ) - 2.0⋅sin(2.0⋅φ)⎟⎥
# ↪ ─────────────────────────────────────────────────────────────────⎟⎥
# ↪                                                                  ⎟⎥
# ↪                                                                  ⎟⎥
# ↪                                                                  ⎠⎦

# %%
sp.pprint([q1, q2_2, q3_2, q4_2])
# Out:
# ⎡                                                                              ↪
# ⎢    ⎛     ⎛                                             __________________⎞⎞  ↪
# ⎢    ⎜     ⎜       3             2                      ╱   2     2        ⎟⎟  ↪
# ⎢    ⎜0.04⋅⎝25.0⋅px  + 25.0⋅px⋅py  - 4.0⋅px - 10.0⋅py⋅╲╱  px  + py  - 0.16 ⎠⎟  ↪
# ⎢asin⎜──────────────────────────────────────────────────────────────────────⎟, ↪
# ⎢    ⎜                                 __________________                   ⎟  ↪
# ⎢    ⎜                  ⎛  2     2⎞   ╱   2     2                           ⎟  ↪
# ⎣    ⎝                  ⎝px  + py ⎠⋅╲╱  px  + py  - 0.16                    ⎠  ↪
#
# ↪      ⎛                                                                       ↪
# ↪      ⎜                                                                       ↪
# ↪      ⎜              4   2                4                          4        ↪
# ↪      ⎜3.90625e+18⋅px ⋅pz  + 1.5625e+18⋅px ⋅pz⋅cos(φ) + 1.5625e+18⋅px ⋅pz + 3 ↪
# ↪  asin⎜────────────────────────────────────────────────────────────────────── ↪
# ↪      ⎜                                                                       ↪
# ↪      ⎜                                                                       ↪
# ↪      ⎝                                                                       ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪            4                       4                            4            ↪
# ↪ .125e+17⋅px ⋅cos(φ) + 7.8125e+16⋅px ⋅cos(2.0⋅φ) + 2.34375e+17⋅px  + 7.8125e+ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪      2   2   2               2   2                         2   2             ↪
# ↪ 18⋅px ⋅py ⋅pz  + 3.125e+18⋅px ⋅py ⋅pz⋅cos(φ) + 3.125e+18⋅px ⋅py ⋅pz + 6.25e+ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪      2   2                       2   2                           2   2       ↪
# ↪ 17⋅px ⋅py ⋅cos(φ) + 1.5625e+17⋅px ⋅py ⋅cos(2.0⋅φ) + 4.6875e+17⋅px ⋅py  + 7.8 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪           2   4              2   3                     2   3               2 ↪
# ↪ 125e+18⋅px ⋅pz  + 6.25e+18⋅px ⋅pz ⋅cos(φ) + 6.25e+18⋅px ⋅pz  - 3.125e+18⋅px  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪         __________________                                                   ↪
# ↪    2   ╱   2     2                             2   2                       2 ↪
# ↪ ⋅pz ⋅╲╱  px  + py  - 0.16 ⋅sin(φ) + 3.75e+18⋅px ⋅pz ⋅cos(φ) + 4.6875e+17⋅px  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                            _________________ ↪
# ↪    2                            2   2              2      ╱   2     2        ↪
# ↪ ⋅pz ⋅cos(2.0⋅φ) + 2.03125e+18⋅px ⋅pz  - 1.25e+18⋅px ⋅pz⋅╲╱  px  + py  - 0.16 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ _                             __________________                             ↪
# ↪                       2      ╱   2     2                                   2 ↪
# ↪  ⋅sin(φ) - 6.25e+17⋅px ⋅pz⋅╲╱  px  + py  - 0.16 ⋅sin(2.0⋅φ) + 5.3125e+17⋅px  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                          2                             2                     ↪
# ↪ ⋅pz⋅cos(φ) + 1.875e+17⋅px ⋅pz⋅cos(2.0⋅φ) - 3.125e+16⋅px ⋅pz⋅cos(3.0⋅φ) + 3.1 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                    _________ ↪
# ↪                                             __________________    ╱          ↪
# ↪          2                             2   ╱   2     2           ╱           ↪
# ↪ 25e+17⋅px ⋅pz - 5.52427172801991e+18⋅px ⋅╲╱  px  + py  - 0.16 ⋅╲╱   - 0.5⋅px ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪ 4   2         4                   4             4                 4          ↪
# ↪  ⋅pz  - 0.2⋅px ⋅pz⋅cos(φ) - 0.2⋅px ⋅pz - 0.04⋅px ⋅cos(φ) - 0.01⋅px ⋅cos(2.0⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪             4     2   2   2         2   2                   2   2            ↪
# ↪ φ) - 0.03⋅px  - px ⋅py ⋅pz  - 0.4⋅px ⋅py ⋅pz⋅cos(φ) - 0.4⋅px ⋅py ⋅pz - 0.08⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪   2   2                 2   2                     2   2     2   4         2  ↪
# ↪ px ⋅py ⋅cos(φ) - 0.02⋅px ⋅py ⋅cos(2.0⋅φ) - 0.06⋅px ⋅py  - px ⋅pz  - 0.8⋅px ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                          0.5                 ↪
# ↪   3                2   3         2   2 ⎛  2     2       ⎞                    ↪
# ↪ pz ⋅cos(φ) - 0.8⋅px ⋅pz  + 0.4⋅px ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.48⋅p ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪  2   2                 2   2                     2   2          2    ⎛  2    ↪
# ↪ x ⋅pz ⋅cos(φ) - 0.06⋅px ⋅pz ⋅cos(2.0⋅φ) + 0.24⋅px ⋅pz  + 0.16⋅px ⋅pz⋅⎝px  +  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪            0.5                                        0.5                    ↪
# ↪   2       ⎞                    2    ⎛  2     2       ⎞                       ↪
# ↪ py  - 0.16⎠   ⋅sin(φ) + 0.08⋅px ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.132 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪    2                     2                         2                         ↪
# ↪ ⋅px ⋅pz⋅cos(φ) - 0.024⋅px ⋅pz⋅cos(2.0⋅φ) + 0.004⋅px ⋅pz⋅cos(3.0⋅φ) + 0.16⋅px ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                   0.5                                      0 ↪
# ↪ 2             2 ⎛  2     2       ⎞                     2 ⎛  2     2       ⎞  ↪
# ↪  ⋅pz + 0.02⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.016⋅px ⋅⎝px  + py  - 0.16⎠  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪ .5                                          0.5                              ↪
# ↪                         2 ⎛  2     2       ⎞                          2      ↪
# ↪   ⋅sin(2.0⋅φ) + 0.004⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0392⋅px ⋅cos( ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪               2    2                 2                       2               ↪
# ↪ φ) + 0.0008⋅px ⋅cos (2.0⋅φ) + 0.01⋅px ⋅cos(2.0⋅φ) + 0.0008⋅px ⋅cos(3.0⋅φ) +  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪          2         4   2         4                   4             4         ↪
# ↪ 0.0292⋅px  - 0.5⋅py ⋅pz  - 0.2⋅py ⋅pz⋅cos(φ) - 0.2⋅py ⋅pz - 0.04⋅py ⋅cos(φ)  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪          4                     4     2   4         2   3                2    ↪
# ↪ - 0.01⋅py ⋅cos(2.0⋅φ) - 0.03⋅py  - py ⋅pz  - 0.8⋅py ⋅pz ⋅cos(φ) - 0.8⋅py ⋅pz ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                   0.5                                        ↪
# ↪ 3         2   2 ⎛  2     2       ⎞                    2   2                  ↪
# ↪   + 0.4⋅py ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.48⋅py ⋅pz ⋅cos(φ) - 0.06⋅py ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                 0.5          ↪
# ↪ 2   2                     2   2          2    ⎛  2     2       ⎞             ↪
# ↪  ⋅pz ⋅cos(2.0⋅φ) + 0.24⋅py ⋅pz  + 0.16⋅py ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                0.5                                           ↪
# ↪         2    ⎛  2     2       ⎞                         2                    ↪
# ↪  0.08⋅py ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.132⋅py ⋅pz⋅cos(φ) - 0.024⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪   2                         2                        2             2 ⎛  2    ↪
# ↪ py ⋅pz⋅cos(2.0⋅φ) + 0.004⋅py ⋅pz⋅cos(3.0⋅φ) + 0.16⋅py ⋅pz + 0.02⋅py ⋅⎝px  +  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪            0.5                                      0.5                      ↪
# ↪   2       ⎞                     2 ⎛  2     2       ⎞                         ↪
# ↪ py  - 0.16⎠   ⋅sin(φ) + 0.016⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.004⋅p ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                      0.5                                                     ↪
# ↪  2 ⎛  2     2       ⎞                          2                   2    2    ↪
# ↪ y ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0392⋅py ⋅cos(φ) + 0.0008⋅py ⋅cos (2. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪               2                       2                       2         6    ↪
# ↪ 0⋅φ) + 0.01⋅py ⋅cos(2.0⋅φ) + 0.0008⋅py ⋅cos(3.0⋅φ) + 0.0292⋅py  - 0.5⋅pz  -  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                      0.5                     ↪
# ↪       5                5         4 ⎛  2     2       ⎞                   4    ↪
# ↪ 0.6⋅pz ⋅cos(φ) - 0.6⋅pz  + 0.4⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.6⋅pz ⋅co ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                    0.5       ↪
# ↪               4                     4          3 ⎛  2     2       ⎞          ↪
# ↪ s(φ) - 0.13⋅pz ⋅cos(2.0⋅φ) + 0.19⋅pz  + 0.32⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                0.5                                           ↪
# ↪            3 ⎛  2     2       ⎞                        3                  3  ↪
# ↪ ) + 0.16⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.22⋅pz ⋅cos(φ) - 0.104⋅pz ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                      3                      3           2 ⎛  2     2       ⎞ ↪
# ↪ cos(2.0⋅φ) - 0.012⋅pz ⋅cos(3.0⋅φ) + 0.312⋅pz  - 0.132⋅pz ⋅⎝px  + py  - 0.16⎠ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪ 0.5                                      0.5                                 ↪
# ↪                      2 ⎛  2     2       ⎞                        2 ⎛  2      ↪
# ↪    ⋅sin(φ) + 0.096⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.02⋅pz ⋅⎝px  + py ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪          0.5                                                                 ↪
# ↪ 2       ⎞                         2                   2    2                 ↪
# ↪   - 0.16⎠   ⋅sin(3.0⋅φ) + 0.228⋅pz ⋅cos(φ) - 0.0008⋅pz ⋅cos (2.0⋅φ) + 0.0228 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪    2                       2                      2             ⎛  2     2   ↪
# ↪ ⋅pz ⋅cos(2.0⋅φ) - 0.0072⋅pz ⋅cos(3.0⋅φ) + 0.106⋅pz  - 0.0784⋅pz⋅⎝px  + py  - ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪       0.5                                      0.5                           ↪
# ↪      ⎞                       ⎛  2     2       ⎞                          ⎛   ↪
# ↪  0.16⎠   ⋅sin(φ) - 0.0288⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.008⋅pz⋅⎝px ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                0.5                                          0.5              ↪
# ↪ 2     2       ⎞                           ⎛  2     2       ⎞                 ↪
# ↪   + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0008⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(4.0⋅φ) + ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                    2                                         ↪
# ↪  0.03224⋅pz⋅cos(φ) - 0.00032⋅pz⋅cos (2.0⋅φ) + 0.01744⋅pz⋅cos(2.0⋅φ) - 0.0002 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                          0.5                 ↪
# ↪                                        ⎛  2     2       ⎞                    ↪
# ↪ 4⋅pz⋅cos(3.0⋅φ) + 0.01488⋅pz - 0.01096⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.0083 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                     0.5                                        0.5           ↪
# ↪   ⎛  2     2       ⎞                         ⎛  2     2       ⎞              ↪
# ↪ 2⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) - 0.00168⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                               0.5                                            ↪
# ↪             ⎛  2     2       ⎞                                               ↪
# ↪ ) + 0.00016⋅⎝px  + py  - 0.16⎠   ⋅sin(4.0⋅φ) - 0.000144⋅cos(φ) - 0.00016⋅cos ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ________________________________________________________________             ↪
# ↪                                                                              ↪
# ↪ 2                                                                            ↪
# ↪  (2.0⋅φ) + 0.000608⋅cos(2.0⋅φ) + 0.000144⋅cos(3.0⋅φ) - 0.000448  - 1.5625e+1 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪          __________________                          __________________      ↪
# ↪     2   ╱   2     2                             2   ╱   2     2              ↪
# ↪ 7⋅px ⋅╲╱  px  + py  - 0.16 ⋅sin(φ) - 1.25e+17⋅px ⋅╲╱  px  + py  - 0.16 ⋅sin( ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                           __________________                                 ↪
# ↪                      2   ╱   2     2                                         ↪
# ↪ 2.0⋅φ) - 3.125e+16⋅px ⋅╲╱  px  + py  - 0.16 ⋅sin(3.0⋅φ) + 3.31456303681194e+ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪            _________________________________________________________________ ↪
# ↪           ╱                                                                  ↪
# ↪      2   ╱          4   2         4                   4             4        ↪
# ↪ 18⋅px ⋅╲╱   - 0.5⋅px ⋅pz  - 0.2⋅px ⋅pz⋅cos(φ) - 0.2⋅px ⋅pz - 0.04⋅px ⋅cos(φ) ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪           4                     4     2   2   2         2   2                ↪
# ↪  - 0.01⋅px ⋅cos(2.0⋅φ) - 0.03⋅px  - px ⋅py ⋅pz  - 0.4⋅px ⋅py ⋅pz⋅cos(φ) - 0. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪     2   2             2   2                 2   2                     2   2  ↪
# ↪ 4⋅px ⋅py ⋅pz - 0.08⋅px ⋅py ⋅cos(φ) - 0.02⋅px ⋅py ⋅cos(2.0⋅φ) - 0.06⋅px ⋅py   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪     2   4         2   3                2   3         2   2 ⎛  2     2        ↪
# ↪ - px ⋅pz  - 0.8⋅px ⋅pz ⋅cos(φ) - 0.8⋅px ⋅pz  + 0.4⋅px ⋅pz ⋅⎝px  + py  - 0.16 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪  0.5                                                                         ↪
# ↪ ⎞                    2   2                 2   2                     2   2   ↪
# ↪ ⎠   ⋅sin(φ) - 0.48⋅px ⋅pz ⋅cos(φ) - 0.06⋅px ⋅pz ⋅cos(2.0⋅φ) + 0.24⋅px ⋅pz  + ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                0.5                                        0. ↪
# ↪         2    ⎛  2     2       ⎞                    2    ⎛  2     2       ⎞   ↪
# ↪  0.16⋅px ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.08⋅px ⋅pz⋅⎝px  + py  - 0.16⎠   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪ 5                                                                            ↪
# ↪                        2                     2                         2     ↪
# ↪  ⋅sin(2.0⋅φ) + 0.132⋅px ⋅pz⋅cos(φ) - 0.024⋅px ⋅pz⋅cos(2.0⋅φ) + 0.004⋅px ⋅pz⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                       0.5                    ↪
# ↪                     2             2 ⎛  2     2       ⎞                     2 ↪
# ↪ cos(3.0⋅φ) + 0.16⋅px ⋅pz + 0.02⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.016⋅px  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                    0.5                                          0.5          ↪
# ↪  ⎛  2     2       ⎞                         2 ⎛  2     2       ⎞             ↪
# ↪ ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.004⋅px ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪               2                   2    2                 2                   ↪
# ↪ φ) + 0.0392⋅px ⋅cos(φ) + 0.0008⋅px ⋅cos (2.0⋅φ) + 0.01⋅px ⋅cos(2.0⋅φ) + 0.00 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪      2                       2         4   2         4                   4   ↪
# ↪ 08⋅px ⋅cos(3.0⋅φ) + 0.0292⋅px  - 0.5⋅py ⋅pz  - 0.2⋅py ⋅pz⋅cos(φ) - 0.2⋅py ⋅p ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪            4                 4                     4     2   4         2   3 ↪
# ↪ z - 0.04⋅py ⋅cos(φ) - 0.01⋅py ⋅cos(2.0⋅φ) - 0.03⋅py  - py ⋅pz  - 0.8⋅py ⋅pz  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                       0.5                    ↪
# ↪                 2   3         2   2 ⎛  2     2       ⎞                    2  ↪
# ↪ ⋅cos(φ) - 0.8⋅py ⋅pz  + 0.4⋅py ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.48⋅py ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪   2                 2   2                     2   2          2    ⎛  2     2 ↪
# ↪ pz ⋅cos(φ) - 0.06⋅py ⋅pz ⋅cos(2.0⋅φ) + 0.24⋅py ⋅pz  + 0.16⋅py ⋅pz⋅⎝px  + py  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪         0.5                                        0.5                       ↪
# ↪        ⎞                    2    ⎛  2     2       ⎞                          ↪
# ↪  - 0.16⎠   ⋅sin(φ) + 0.08⋅py ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.132⋅py ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪ 2                     2                         2                        2   ↪
# ↪  ⋅pz⋅cos(φ) - 0.024⋅py ⋅pz⋅cos(2.0⋅φ) + 0.004⋅py ⋅pz⋅cos(3.0⋅φ) + 0.16⋅py ⋅p ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                0.5                                      0.5  ↪
# ↪            2 ⎛  2     2       ⎞                     2 ⎛  2     2       ⎞     ↪
# ↪ z + 0.02⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.016⋅py ⋅⎝px  + py  - 0.16⎠   ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                          0.5                                 ↪
# ↪                      2 ⎛  2     2       ⎞                          2         ↪
# ↪ sin(2.0⋅φ) + 0.004⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0392⋅py ⋅cos(φ)  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪            2    2                 2                       2                  ↪
# ↪ + 0.0008⋅py ⋅cos (2.0⋅φ) + 0.01⋅py ⋅cos(2.0⋅φ) + 0.0008⋅py ⋅cos(3.0⋅φ) + 0.0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                          0.5 ↪
# ↪       2         6         5                5         4 ⎛  2     2       ⎞    ↪
# ↪ 292⋅py  - 0.5⋅pz  - 0.6⋅pz ⋅cos(φ) - 0.6⋅pz  + 0.4⋅pz ⋅⎝px  + py  - 0.16⎠    ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                 4                 4                     4          3 ⎛  2    ↪
# ↪ ⋅sin(φ) - 0.6⋅pz ⋅cos(φ) - 0.13⋅pz ⋅cos(2.0⋅φ) + 0.19⋅pz  + 0.32⋅pz ⋅⎝px  +  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪            0.5                                     0.5                       ↪
# ↪   2       ⎞                    3 ⎛  2     2       ⎞                        3 ↪
# ↪ py  - 0.16⎠   ⋅sin(φ) + 0.16⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.22⋅pz  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                   3                      3                      3            ↪
# ↪ ⋅cos(φ) - 0.104⋅pz ⋅cos(2.0⋅φ) - 0.012⋅pz ⋅cos(3.0⋅φ) + 0.312⋅pz  - 0.132⋅pz ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                     0.5                                      0.5             ↪
# ↪ 2 ⎛  2     2       ⎞                     2 ⎛  2     2       ⎞                ↪
# ↪  ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.096⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ)  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                              0.5                                             ↪
# ↪          2 ⎛  2     2       ⎞                         2                   2  ↪
# ↪ + 0.02⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.228⋅pz ⋅cos(φ) - 0.0008⋅pz ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪    2                   2                       2                      2      ↪
# ↪ cos (2.0⋅φ) + 0.0228⋅pz ⋅cos(2.0⋅φ) - 0.0072⋅pz ⋅cos(3.0⋅φ) + 0.106⋅pz  - 0. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                           0.5                                      0.5       ↪
# ↪         ⎛  2     2       ⎞                       ⎛  2     2       ⎞          ↪
# ↪ 0784⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.0288⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(2 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                    0.5                                       ↪
# ↪                  ⎛  2     2       ⎞                           ⎛  2     2     ↪
# ↪ .0⋅φ) + 0.008⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0008⋅pz⋅⎝px  + py  - 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ...
# ↪      2       ⎞                          2                   2    2           ↪
# ↪  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.0392⋅px ⋅cos(φ) + 0.0008⋅px ⋅cos (2.0⋅φ) +  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪        2                       2                       2         4   2       ↪
# ↪ 0.01⋅px ⋅cos(2.0⋅φ) + 0.0008⋅px ⋅cos(3.0⋅φ) + 0.0292⋅px  - 0.5⋅py ⋅pz  - 0.2 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪    4                   4             4                 4                     ↪
# ↪ ⋅py ⋅pz⋅cos(φ) - 0.2⋅py ⋅pz - 0.04⋅py ⋅cos(φ) - 0.01⋅py ⋅cos(2.0⋅φ) - 0.03⋅p ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪  4     2   4         2   3                2   3         2   2 ⎛  2     2     ↪
# ↪ y  - py ⋅pz  - 0.8⋅py ⋅pz ⋅cos(φ) - 0.8⋅py ⋅pz  + 0.4⋅py ⋅pz ⋅⎝px  + py  - 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪     0.5                                                                      ↪
# ↪    ⎞                    2   2                 2   2                     2    ↪
# ↪ .16⎠   ⋅sin(φ) - 0.48⋅py ⋅pz ⋅cos(φ) - 0.06⋅py ⋅pz ⋅cos(2.0⋅φ) + 0.24⋅py ⋅pz ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                    2         ↪
# ↪                                                            250.0⋅px  + 250.0 ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                   0.5                                        ↪
# ↪ 2          2    ⎛  2     2       ⎞                    2    ⎛  2     2        ↪
# ↪   + 0.16⋅py ⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.08⋅py ⋅pz⋅⎝px  + py  - 0.16 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                         0.5  ↪
# ↪    2           2                                      ⎛  2     2       ⎞     ↪
# ↪ ⋅py  + 250.0⋅pz  + 100.0⋅pz⋅cos(φ) + 100.0⋅pz - 100.0⋅⎝px  + py  - 0.16⎠   ⋅ ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪  0.5                                                                         ↪
# ↪ ⎞                         2                     2                         2  ↪
# ↪ ⎠   ⋅sin(2.0⋅φ) + 0.132⋅py ⋅pz⋅cos(φ) - 0.024⋅py ⋅pz⋅cos(2.0⋅φ) + 0.004⋅py ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ sin(φ) + 20.0⋅cos(φ) - 20.0                                                  ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                          0.5                 ↪
# ↪                        2             2 ⎛  2     2       ⎞                    ↪
# ↪ pz⋅cos(3.0⋅φ) + 0.16⋅py ⋅pz + 0.02⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.016⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                       0.5                                          0.5       ↪
# ↪   2 ⎛  2     2       ⎞                         2 ⎛  2     2       ⎞          ↪
# ↪ py ⋅⎝px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.004⋅py ⋅⎝px  + py  - 0.16⎠   ⋅sin(3 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                  2                   2    2                 2                ↪
# ↪ .0⋅φ) + 0.0392⋅py ⋅cos(φ) + 0.0008⋅py ⋅cos (2.0⋅φ) + 0.01⋅py ⋅cos(2.0⋅φ) + 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪         2                       2         6         5                5       ↪
# ↪ .0008⋅py ⋅cos(3.0⋅φ) + 0.0292⋅py  - 0.5⋅pz  - 0.6⋅pz ⋅cos(φ) - 0.6⋅pz  + 0.4 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                        0.5                                                   ↪
# ↪    4 ⎛  2     2       ⎞                   4                 4                ↪
# ↪ ⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.6⋅pz ⋅cos(φ) - 0.13⋅pz ⋅cos(2.0⋅φ) + 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                      0.5                                     ↪
# ↪       4          3 ⎛  2     2       ⎞                    3 ⎛  2     2        ↪
# ↪ .19⋅pz  + 0.32⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.16⋅pz ⋅⎝px  + py  - 0.16 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪  0.5                                                                         ↪
# ↪ ⎞                        3                  3                      3         ↪
# ↪ ⎠   ⋅sin(2.0⋅φ) + 0.22⋅pz ⋅cos(φ) - 0.104⋅pz ⋅cos(2.0⋅φ) - 0.012⋅pz ⋅cos(3.0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                               0.5                            ↪
# ↪               3           2 ⎛  2     2       ⎞                     2 ⎛  2    ↪
# ↪ ⋅φ) + 0.312⋅pz  - 0.132⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) + 0.096⋅pz ⋅⎝px  +  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪            0.5                                         0.5                   ↪
# ↪   2       ⎞                        2 ⎛  2     2       ⎞                      ↪
# ↪ py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.02⋅pz ⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.22 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪     2                   2    2                   2                       2   ↪
# ↪ 8⋅pz ⋅cos(φ) - 0.0008⋅pz ⋅cos (2.0⋅φ) + 0.0228⋅pz ⋅cos(2.0⋅φ) - 0.0072⋅pz ⋅c ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                     0.5                      ↪
# ↪                     2             ⎛  2     2       ⎞                       ⎛ ↪
# ↪ os(3.0⋅φ) + 0.106⋅pz  - 0.0784⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.0288⋅pz⋅⎝ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                  0.5                                         0.5             ↪
# ↪   2     2       ⎞                          ⎛  2     2       ⎞                ↪
# ↪ px  + py  - 0.16⎠   ⋅sin(2.0⋅φ) + 0.008⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ)  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                               0.5                                            ↪
# ↪             ⎛  2     2       ⎞                                               ↪
# ↪ + 0.0008⋅pz⋅⎝px  + py  - 0.16⎠   ⋅sin(4.0⋅φ) + 0.03224⋅pz⋅cos(φ) - 0.00032⋅p ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪      2                                                                       ↪
# ↪ z⋅cos (2.0⋅φ) + 0.01744⋅pz⋅cos(2.0⋅φ) - 0.00024⋅pz⋅cos(3.0⋅φ) + 0.01488⋅pz - ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                            0.5                                    0.5        ↪
# ↪          ⎛  2     2       ⎞                     ⎛  2     2       ⎞           ↪
# ↪  0.01096⋅⎝px  + py  - 0.16⎠   ⋅sin(φ) - 0.00832⋅⎝px  + py  - 0.16⎠   ⋅sin(2. ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                  0.5                                         ↪
# ↪                ⎛  2     2       ⎞                         ⎛  2     2       ⎞ ↪
# ↪ 0⋅φ) - 0.00168⋅⎝px  + py  - 0.16⎠   ⋅sin(3.0⋅φ) + 0.00016⋅⎝px  + py  - 0.16⎠ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪ 0.5                                                                          ↪
# ↪                                               2                              ↪
# ↪    ⋅sin(4.0⋅φ) - 0.000144⋅cos(φ) - 0.00016⋅cos (2.0⋅φ) + 0.000608⋅cos(2.0⋅φ) ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________________                               ⎞⎤
# ↪                                                                  ⎟⎥
# ↪                                                                  ⎟⎥
# ↪  + 0.000144⋅cos(3.0⋅φ) - 0.000448  + 20.0⋅sin(φ) - 2.0⋅sin(2.0⋅φ)⎟⎥
# ↪ ─────────────────────────────────────────────────────────────────⎟⎥
# ↪                                                                  ⎟⎥
# ↪                                                                  ⎟⎥
# ↪                                                                  ⎠⎦
